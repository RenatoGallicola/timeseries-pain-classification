# %% [markdown]
# # Experiment — CNN-GRU with Optuna search
#
# Same architecture as the baseline, with an Optuna study over hidden size, number of layers, dropout, learning rate, weight decay and label smoothing.
#
# **Best validation weighted-F1: 0.9262** — no improvement over the hand-tuned baseline, so the search space was later moved to the windowing parameters instead.
#
# ---

# %% [markdown]
# ## Google Drive Connection

# %%
# --- Paths ---------------------------------------------------------------
# Originally executed on Google Colab with the dataset on Google Drive.
# DATA_DIR must contain: pirate_pain_train.csv, pirate_pain_train_labels.csv,
# pirate_pain_test.csv, sample_submission.csv  (see data/README.md)
import os

DATA_DIR = os.environ.get("PIRATE_DATA_DIR", "data")
os.makedirs("models", exist_ok=True)
os.makedirs("artifacts", exist_ok=True)

# %% [markdown]
# ## Libraries Import

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
logs_dir = "tensorboard"
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
import optuna
from optuna.trial import Trial
from optuna.samplers import TPESampler

from sklearn.model_selection import StratifiedKFold
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# ## Exploration and Data Analysis

# %%
X_train = pd.read_csv('../Dataset/pirate_pain_train.csv')
y_train = pd.read_csv('../Dataset/pirate_pain_train_labels.csv')

X_test = pd.read_csv('../Dataset/pirate_pain_test.csv')

# %%
# Check for and drop columns with only one unique value
cols_to_drop = []
for col in X_train.columns:
  if X_train[col].nunique() == 1:
    print(f"Column '{col}' has only one unique value")
    cols_to_drop.append(col)

X_train = X_train.drop(columns=cols_to_drop)
# Out:
# Column 'joint_30' has only one unique value

# %%
# Define a mapping for string representations of strings to integers
legs_mapping = {
    'two': 2,
    'one+peg_leg': 1
}

hands_mapping = {
    'two': 2,
    'one+hook_hand': 1
}

eyes_mapping = {
    'two': 2,
    'one+eye_patch': 1
}

# Convert 'n_legs', 'n_hands', and 'n_eyes' to integers using the mapping
X_train['n_legs'] = X_train['n_legs'].map(legs_mapping)
X_train['n_hands'] = X_train['n_hands'].map(hands_mapping)
X_train['n_eyes'] = X_train['n_eyes'].map(eyes_mapping)

X_test['n_legs'] = X_test['n_legs'].map(legs_mapping)
X_test['n_hands'] = X_test['n_hands'].map(hands_mapping)
X_test['n_eyes'] = X_test['n_eyes'].map(eyes_mapping)

# %%
# Convert 'joint_*' columns to float32 data type to use less memory
for col in X_train.columns:
  if 'joint' in col:
    X_train[col] = X_train[col].astype(np.float32)

for col in X_test.columns:
  if 'joint' in col:
    X_test[col] = X_test[col].astype(np.float32)

# %%
# Define a mapping of status names to integer labels
label_mapping = {
    'no_pain': 0,
    'low_pain': 1,
    'high_pain': 2
}

# Map status names to integers in the labels set
y_train['label'] = y_train['label'].map(label_mapping)

# %%
# Merge features + labels
train_df = X_train.merge(y_train, on="sample_index")
test_df = X_test.copy()

# %%
# Define the columns to be normalised
num_joints = 29
scale_columns = [f'joint_{i:02d}' for i in range(num_joints+1)]

def normalize_minmax(df_train, df_val, df_test):
    mins = df_train[scale_columns].min()
    maxs = df_train[scale_columns].max()
    for col in scale_columns:
        for df in [df_train, df_val, df_test]:
            df[col] = (df[col] - mins[col]) / (maxs[col] - mins[col])
    return df_train, df_val, df_test

# %%
# Define the window size
WINDOW_SIZE = 200

# Define the stride for overlapping windows (so it defines the lenght of the sequence)
STRIDE = 50

# %%
# @title
# Define a function to build sequences from the dataset
def build_sequences(df, window=200, stride=200, is_test=False):
    # Sanity check to ensure the window is divisible by the stride
    assert window % stride == 0

    # Initialise lists to store sequences and their corresponding labels
    dataset = []
    labels = []

    num_surveys = 4
    num_joints = 29
    rel_col = [f'pain_survey_{i+1}' for i in range(num_surveys)] + [f'joint_{i:02d}' for i in range(num_joints+1)]

    # Iterate over unique IDs in the DataFrame
    for id in df['sample_index'].unique():
        # Extract sensor data for the current ID
        temp = df[df['sample_index'] == id][rel_col].values

        # Retrieve the activity label for the current ID only if not the test set
        if not is_test:
            label = y_train[y_train['sample_index'] == id]['label'].values[0]

        # Calculate padding length to ensure full windows (to avoid the last sequence to be shorter than the others)
        padding_len = window - len(temp) % window

        # Create zero padding and concatenate with the data
        padding = np.zeros((padding_len, len(rel_col)), dtype='float32')
        temp = np.concatenate((temp, padding))

        # Build feature windows and associate them with labels
        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            if not is_test:
              labels.append(label)
            idx += stride


    # Convert lists to numpy arrays for further processing
    dataset = np.array(dataset)
    labels = np.array(labels)

    if is_test:
        return dataset
    else:
        return dataset, labels

# %%
# @title
def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Get labels from the dataset for weighted sampling
    if hasattr(ds, 'tensors'):
        # For TensorDataset, labels are the second tensor
        dataset_labels = ds.tensors[1].numpy() if len(ds.tensors) > 1 else None
    elif hasattr(ds, 'labels'):
        # For custom datasets with a 'labels' attribute
        dataset_labels = ds.labels
    else:
        dataset_labels = None

    sampler = None
    if dataset_labels is not None and shuffle:
        class_counts = np.bincount(dataset_labels)
        # Avoid division by zero
        class_weights = 1.0 / (class_counts + 1e-9)
        sample_weights = class_weights[dataset_labels]
        from torch.utils.data import WeightedRandomSampler
        sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
        shuffle = False # Shuffle is handled by the sampler

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
        sampler=sampler # Use the sampler if created
    )

# %% [markdown]
# ## Model Building

# %%
input_shape = (200, 34)
num_classes = 3

# %%
# @title
def recurrent_summary(model, input_size):
    """Custom summary function that emulates torchinfo's output while correctly
    counting parameters for RNN/GRU/LSTM layers.

    This function is designed for models whose direct children are
    nn.Linear, nn.RNN, nn.GRU, or nn.LSTM layers.

    Args:
        model (nn.Module): The model to analyze.
        input_size (tuple): Shape of the input tensor (e.g., (seq_len, features)).
    """

    # Dictionary to store output shapes captured by forward hooks
    output_shapes = {}
    # List to track hook handles for later removal
    hooks = []

    def get_hook(name):
        """Factory function to create a forward hook for a specific module."""
        def hook(module, input, output):
            # Handle RNN layer outputs (returns a tuple)
            if isinstance(output, tuple):
                # output[0]: all hidden states with shape (batch, seq_len, hidden*directions)
                shape1 = list(output[0].shape)
                shape1[0] = -1  # Replace batch dimension with -1

                # output[1]: final hidden state h_n (or tuple (h_n, c_n) for LSTM)
                if isinstance(output[1], tuple):  # LSTM case: (h_n, c_n)
                    shape2 = list(output[1][0].shape)  # Extract h_n only
                else:  # RNN/GRU case: h_n only
                    shape2 = list(output[1].shape)

                # Replace batch dimension (middle position) with -1
                shape2[1] = -1

                output_shapes[name] = f"[{shape1}, {shape2}]"

            # Handle standard layer outputs (e.g., Linear)
            else:
                shape = list(output.shape)
                shape[0] = -1  # Replace batch dimension with -1
                output_shapes[name] = f"{shape}"
        return hook

    # 1. Determine the device where model parameters reside
    try:
        device = next(model.parameters()).device
    except StopIteration:
        device = torch.device("cpu")  # Fallback for models without parameters

    # 2. Create a dummy input tensor with batch_size=1
    dummy_input = torch.randn(1, *input_size).to(device)

    # 3. Register forward hooks on target layers
    # Iterate through direct children of the model (e.g., self.rnn, self.classifier)
    for name, module in model.named_children():
        if isinstance(module, (nn.Linear, nn.RNN, nn.GRU, nn.LSTM)):
            # Register the hook and store its handle for cleanup
            hook_handle = module.register_forward_hook(get_hook(name))
            hooks.append(hook_handle)

    # 4. Execute a dummy forward pass in evaluation mode
    model.eval()
    with torch.no_grad():
        try:
            model(dummy_input)
        except Exception as e:
            print(f"Error during dummy forward pass: {e}")
            # Clean up hooks even if an error occurs
            for h in hooks:
                h.remove()
            return

    # 5. Remove all registered hooks
    for h in hooks:
        h.remove()

    # --- 6. Print the summary table ---

    print("-" * 79)
    # Column headers
    print(f"{'Layer (type)':<25} {'Output Shape':<28} {'Param #':<18}")
    print("=" * 79)

    total_params = 0
    total_trainable_params = 0

    # Iterate through modules again to collect and display parameter information
    for name, module in model.named_children():
        if name in output_shapes:
            # Count total and trainable parameters for this module
            module_params = sum(p.numel() for p in module.parameters())
            trainable_params = sum(p.numel() for p in module.parameters() if p.requires_grad)

            total_params += module_params
            total_trainable_params += trainable_params

            # Format strings for display
            layer_name = f"{name} ({type(module).__name__})"
            output_shape_str = str(output_shapes[name])
            params_str = f"{trainable_params:,}"

            print(f"{layer_name:<25} {output_shape_str:<28} {params_str:<15}")

    print("=" * 79)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {total_trainable_params:,}")
    print(f"Non-trainable params: {total_params - total_trainable_params:,}")
    print("-" * 79)

# %%
# @title
import torch
from torch import nn

class CNN_GRU_Classifier(nn.Module):
    """Hybrid CNN + GRU classifier for multivariate time series.
    Captures local temporal patterns via CNN and global dependencies via GRU.
    """

    def __init__(
        self,
        input_size: int,
        num_classes: int,
        hidden_size: int = 128,
        num_layers: int = 2,
        dropout_rate: float = 0.3,
        bidirectional: bool = False,
        use_attention: bool = True,
    ):
        super().__init__()

        self.bidirectional = bidirectional
        self.use_attention = use_attention
        gru_input_size = 128

        # --- CNN feature extractor ---
        self.cnn = nn.Sequential(
            nn.Conv1d(input_size, 64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Conv1d(64, gru_input_size, kernel_size=3, padding=1),
            nn.BatchNorm1d(gru_input_size),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
        )

        # --- GRU encoder ---
        self.gru = nn.GRU(
            input_size=gru_input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout_rate if num_layers > 1 else 0,
            bidirectional=bidirectional,
        )

        # --- Optional Attention Pooling ---
        if use_attention:
            self.attention = nn.Sequential(
                nn.Linear(hidden_size * (2 if bidirectional else 1), 64),
                nn.Tanh(),
                nn.Linear(64, 1, bias=False)
            )

        # --- Final classifier ---
        fc_input = hidden_size * (2 if bidirectional else 1)
        self.fc = nn.Sequential(
            nn.Linear(fc_input, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, num_classes),
        )

    def forward(self, x):
        """
        x shape: (batch_size, seq_len, input_size)
        """
        # CNN expects (batch, features, seq_len)
        x = x.permute(0, 2, 1)
        x = self.cnn(x)
        x = x.permute(0, 2, 1)

        # GRU encoding
        out, _ = self.gru(x)

        if self.use_attention:
            # Attention weights
            attn_weights = torch.softmax(self.attention(out), dim=1)
            x = torch.sum(out * attn_weights, dim=1)
        else:
            # Mean pooling
            x = out.mean(dim=1)

        return self.fc(x)


# Create model and display architecture with parameter count
rnn_model = CNN_GRU_Classifier(
    input_size=input_shape[-1],
    num_classes=num_classes,
    hidden_size=128,
    num_layers=2,
    dropout_rate=0.,
    bidirectional=False,
    use_attention=True  # or False for plain mean pooling
).to(device)
recurrent_summary(rnn_model, input_size=input_shape)
# Out:
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# gru (GRU)                 [[-1, 200, 128], [2, -1, 128]] 198,144
# ===============================================================================
# Total params: 198,144
# Trainable params: 198,144
# Non-trainable params: 0
# -------------------------------------------------------------------------------

# %% [markdown]
# ## Network and Training Hyperparameters

# %% [markdown]
# ## Model Training

# %%
# @title
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
# @title
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU) and convert to float32
        inputs, targets = inputs.to(device).float(), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
# @title
def validate_one_epoch(model, val_loader, criterion, device):
    """Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device).float(), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
# @title
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name="", base_path="", scheduler=None):
    """Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        if scheduler is not None:
            metric_to_track = val_f1 if evaluation_metric == "val_f1" else val_loss
            scheduler.step(metric_to_track)

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        # if writer is not None:
        #     log_metrics_to_tensorboard(
        #         writer, epoch, train_loss, train_f1, val_loss, val_f1, model
        #     )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), base_path+"models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load(base_path+"models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), base_path+"models/"+experiment_name+'_model.pt')

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# ## Optuna

# %%
def objective(trial):
    # === Hyperparameter search space ===
    lr = trial.suggest_loguniform("lr", 1e-4, 1e-2)
    batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
    hidden_size = trial.suggest_int("hidden_size", 64, 256, step=64)
    num_layers = trial.suggest_int("num_layers", 1, 3)
    dropout_rate = trial.suggest_float("dropout_rate", 0.0, 0.5)
    weight_decay = trial.suggest_loguniform("weight_decay", 1e-6, 1e-3)
    l1_lambda = trial.suggest_loguniform("l1_lambda", 1e-8, 1e-3)
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-8, 1e-3)
    loss_variant = trial.suggest_categorical("loss_variant", ["plain", "weighted", "smoothed"])
    label_smoothing = trial.suggest_float("label_smoothing", 0.0, 0.2) if loss_variant == "smoothed" else 0.0
    scheduler_type = trial.suggest_categorical("scheduler", ["cosine", "onecycle"])
    WINDOW_SIZE = trial.suggest_categorical("window_size", [100, 150, 200, 250])
    STRIDE = trial.suggest_categorical("stride", [25, 50])

    # === K-Fold setup ===
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    y_labels = y_train["label"].values
    unique_ids = train_df["sample_index"].unique()
    f1_scores = []

    # === Iterate folds ===
    for fold, (train_idx, val_idx) in enumerate(skf.split(unique_ids, y_labels)):
        train_ids = unique_ids[train_idx]
        val_ids = unique_ids[val_idx]

        df_train = train_df[train_df["sample_index"].isin(train_ids)].copy()
        df_val   = train_df[train_df["sample_index"].isin(val_ids)].copy()
        df_test  = test_df.copy()

        # === Normalization ===
        df_train, df_val, df_test = normalize_minmax(df_train, df_val, df_test)

        # === Sequence building ===
        X_train_seq, y_train_seq = build_sequences(df_train, WINDOW_SIZE, STRIDE)
        X_val_seq,   y_val_seq   = build_sequences(df_val, WINDOW_SIZE, STRIDE)

        # Define the input shape based on the training data
        input_shape = X_train_seq.shape[1:]

        # Define the number of classes based on the categorical labels
        num_classes = len(np.unique(y_train_seq))

        # === Datasets and Loaders ===
        train_ds = TensorDataset(torch.from_numpy(X_train_seq), torch.from_numpy(y_train_seq))
        val_ds   = TensorDataset(torch.from_numpy(X_val_seq),   torch.from_numpy(y_val_seq))

        train_loader = make_loader(train_ds, batch_size, shuffle=True, drop_last=False)
        val_loader   = make_loader(val_ds, batch_size, shuffle=False, drop_last=False)

        # === Class weights (for weighted loss) ===
        counts = np.bincount(y_train_seq)
        class_weights = torch.tensor(1.0 / (counts + 1e-9), dtype=torch.float32).to(device)
        class_weights /= class_weights.sum()

        # === Loss ===
        if loss_variant == "weighted":
            criterion = nn.CrossEntropyLoss(weight=class_weights, label_smoothing=label_smoothing)
        else:
            criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

        # === Model & Optimizer ===
        input_size = X_train_seq.shape[2]
        model = CNN_GRU_Classifier(
            input_size=input_size,
            num_classes=num_classes,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout_rate=dropout_rate
        ).to(device)

        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
        scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))

        # === Scheduler ===
        if scheduler_type == "cosine":
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=10, eta_min=lr / 50
            )
        else:  # onecycle
            scheduler = torch.optim.lr_scheduler.OneCycleLR(
                optimizer, max_lr=lr, steps_per_epoch=len(train_loader), epochs=10
            )

        # === Train model using your fit() ===
        model, history = fit(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=100,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            device=device,
            l1_lambda=l1_lambda,
            l2_lambda=l2_lambda,
            patience=50,  # short early stopping
            evaluation_metric="val_f1",
            scheduler=scheduler,
            verbose=0
        )

        # === Record best F1 ===
        best_f1 = max(history["val_f1"])
        f1_scores.append(best_f1)

        # === Report to Optuna ===
        trial.report(best_f1, step=fold)
        if trial.should_prune():
            raise optuna.TrialPruned()

    return np.mean(f1_scores)

# %%
# study = optuna.create_study(
#     study_name="cnn_gru_timeseries_classification",
#     direction="maximize",
#     sampler=TPESampler(seed=SEED),
#     pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=1)
# )

# n_trials = 30
# study.optimize(objective, n_trials=n_trials, timeout=None, show_progress_bar=True)

# print("Best trial:")
# trial = study.best_trial
# print(f"F1 score: {trial.value}")
# print("Params:")
# for key, value in trial.params.items():
#     print(f"    {key}: {value}")

# %%
best_params = {'lr': 0.009089829469577987, 'batch_size': 16, 'hidden_size': 128, 'num_layers': 2, 'dropout_rate': 0.4917990932678341, 'weight_decay': 0.0002550348937979814, 'l1_lambda': 1.910858969378018e-07, 'l2_lambda': 1.134384198293992e-08, 'loss_variant': 'weighted', 'scheduler': 'onecycle', 'window_size': 100, 'stride': 25}

# %% [markdown]
# ## Model Train

# %%
BASE_PATH = ""

# %%
from sklearn.model_selection import train_test_split

experiment_name = "cnn_gru_nobi_optuna"EPOCHS = 500
PATIENCE = 100

# best_params = study.best_trial.params

unique_ids = train_df["sample_index"].unique()
train_ids, val_ids = train_test_split(
    unique_ids, test_size=0.2, random_state=42, stratify=y_train["label"].values
)

df_train = train_df[train_df["sample_index"].isin(train_ids)].copy()
df_val   = train_df[train_df["sample_index"].isin(val_ids)].copy()
df_test  = test_df.copy()

df_train, df_val, df_test = normalize_minmax(df_train, df_val, df_test)

X_train_seq, y_train_seq = build_sequences(df_train, best_params["window_size"], best_params["stride"])
X_val_seq,   y_val_seq   = build_sequences(df_val, best_params["window_size"], best_params["stride"])

train_ds = TensorDataset(torch.from_numpy(X_train_seq), torch.from_numpy(y_train_seq))
val_ds   = TensorDataset(torch.from_numpy(X_val_seq),   torch.from_numpy(y_val_seq))

train_loader = make_loader(train_ds, best_params["batch_size"], shuffle=True, drop_last=False)
val_loader   = make_loader(val_ds, best_params["batch_size"], shuffle=False, drop_last=False)

num_classes = len(np.unique(y_train_seq))
input_size = X_train_seq.shape[2]

model = CNN_GRU_Classifier(
    input_size=input_size,
    num_classes=num_classes,
    hidden_size=best_params["hidden_size"],
    num_layers=best_params["num_layers"],
    dropout_rate=best_params["dropout_rate"],
    bidirectional=False,
    use_attention=True
).to(device)

counts = np.bincount(y_train_seq)
class_weights = torch.tensor(1.0 / (counts + 1e-9), dtype=torch.float32).to(device)
class_weights /= class_weights.sum()

if best_params["loss_variant"] == "weighted":
    criterion = nn.CrossEntropyLoss(weight=class_weights)
elif best_params["loss_variant"] == "smoothed":
    criterion = nn.CrossEntropyLoss(label_smoothing=best_params["label_smoothing"])
else:
    criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=best_params["lr"],
    weight_decay=best_params["weight_decay"]
)

scaler = torch.cuda.amp.GradScaler(enabled=(device.type == "cuda"))

if best_params["scheduler"] == "cosine":
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=10, eta_min=best_params["lr"] / 50
    )
else:
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=best_params["lr"],
        steps_per_epoch=len(train_loader),
        epochs=20
    )

model, training_history = fit(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=500,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    device=device,
    l1_lambda=best_params["l1_lambda"],
    l2_lambda=best_params["l2_lambda"],
    patience=100,
    evaluation_metric="val_f1",
    scheduler=scheduler,
    verbose=1,
    experiment_name=experiment_name,
    base_path=BASE_PATH
)

# Update best model if current performance is superior
if training_history['val_f1'][-1] > best_performance:
    best_model = rnn_model
    best_performance = training_history['val_f1'][-1]
# Out:
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.7420, F1 Score=0.3668 | Val: Loss=2.3139, F1 Score=0.0576
# Epoch   2/500 | Train: Loss=0.4300, F1 Score=0.5891 | Val: Loss=1.3844, F1 Score=0.4127
# Epoch   3/500 | Train: Loss=0.2672, F1 Score=0.7619 | Val: Loss=1.0228, F1 Score=0.6909
# Epoch   4/500 | Train: Loss=0.1931, F1 Score=0.8636 | Val: Loss=0.9287, F1 Score=0.7606
# Epoch   5/500 | Train: Loss=0.2036, F1 Score=0.8281 | Val: Loss=0.9265, F1 Score=0.7073
# Epoch   6/500 | Train: Loss=0.1384, F1 Score=0.8703 | Val: Loss=0.7247, F1 Score=0.7988
# Epoch   7/500 | Train: Loss=0.1723, F1 Score=0.8607 | Val: Loss=0.6541, F1 Score=0.8138
# Epoch   8/500 | Train: Loss=0.1128, F1 Score=0.9033 | Val: Loss=0.5567, F1 Score=0.7841
# Epoch   9/500 | Train: Loss=0.1161, F1 Score=0.9050 | Val: Loss=0.6571, F1 Score=0.8565
# Epoch  10/500 | Train: Loss=0.1304, F1 Score=0.8963 | Val: Loss=1.2946, F1 Score=0.7122
# Epoch  11/500 | Train: Loss=0.0862, F1 Score=0.9204 | Val: Loss=0.7913, F1 Score=0.8079
# Epoch  12/500 | Train: Loss=0.0956, F1 Score=0.9142 | Val: Loss=0.6958, F1 Score=0.8533
# Epoch  13/500 | Train: Loss=0.0738, F1 Score=0.9385 | Val: Loss=2.0623, F1 Score=0.6966
# Epoch  14/500 | Train: Loss=0.0897, F1 Score=0.9322 | Val: Loss=0.9478, F1 Score=0.7908
# Epoch  15/500 | Train: Loss=0.0574, F1 Score=0.9420 | Val: Loss=1.0993, F1 Score=0.7647
# Epoch  16/500 | Train: Loss=0.0460, F1 Score=0.9577 | Val: Loss=2.7230, F1 Score=0.5037
# Epoch  17/500 | Train: Loss=0.0762, F1 Score=0.9328 | Val: Loss=0.7088, F1 Score=0.8792
# Epoch  18/500 | Train: Loss=0.0795, F1 Score=0.9416 | Val: Loss=0.7343, F1 Score=0.8299
# Epoch  19/500 | Train: Loss=0.0663, F1 Score=0.9398 | Val: Loss=0.9543, F1 Score=0.8039
# Epoch  20/500 | Train: Loss=0.0510, F1 Score=0.9487 | Val: Loss=0.7396, F1 Score=0.8875
# Epoch  21/500 | Train: Loss=0.0540, F1 Score=0.9521 | Val: Loss=0.8328, F1 Score=0.8891
# Epoch  22/500 | Train: Loss=0.0702, F1 Score=0.9395 | Val: Loss=1.0373, F1 Score=0.8279
# Epoch  23/500 | Train: Loss=0.0618, F1 Score=0.9518 | Val: Loss=1.7797, F1 Score=0.5125
# Epoch  24/500 | Train: Loss=0.0575, F1 Score=0.9520 | Val: Loss=0.6663, F1 Score=0.8926
# Epoch  25/500 | Train: Loss=0.0331, F1 Score=0.9736 | Val: Loss=0.6605, F1 Score=0.8914
# Epoch  26/500 | Train: Loss=0.0327, F1 Score=0.9745 | Val: Loss=1.1107, F1 Score=0.7725
# Epoch  27/500 | Train: Loss=0.0606, F1 Score=0.9461 | Val: Loss=0.6303, F1 Score=0.8908
# Epoch  28/500 | Train: Loss=0.0318, F1 Score=0.9694 | Val: Loss=1.2077, F1 Score=0.8194
# Epoch  29/500 | Train: Loss=0.0660, F1 Score=0.9581 | Val: Loss=0.8787, F1 Score=0.8918
# Epoch  30/500 | Train: Loss=0.0283, F1 Score=0.9795 | Val: Loss=0.7429, F1 Score=0.9063
# Epoch  31/500 | Train: Loss=0.0402, F1 Score=0.9644 | Val: Loss=0.8611, F1 Score=0.8189
# Epoch  32/500 | Train: Loss=0.0338, F1 Score=0.9737 | Val: Loss=0.7792, F1 Score=0.8745
# Epoch  33/500 | Train: Loss=0.0665, F1 Score=0.9654 | Val: Loss=1.7747, F1 Score=0.8133
# Epoch  34/500 | Train: Loss=0.0907, F1 Score=0.9418 | Val: Loss=0.6912, F1 Score=0.8930
# Epoch  35/500 | Train: Loss=0.0305, F1 Score=0.9690 | Val: Loss=0.7952, F1 Score=0.8947
# Epoch  36/500 | Train: Loss=0.0250, F1 Score=0.9798 | Val: Loss=0.8494, F1 Score=0.8934
# Epoch  37/500 | Train: Loss=0.0491, F1 Score=0.9611 | Val: Loss=0.8782, F1 Score=0.8732
# Epoch  38/500 | Train: Loss=0.0280, F1 Score=0.9786 | Val: Loss=0.6757, F1 Score=0.8932
# Epoch  39/500 | Train: Loss=0.0451, F1 Score=0.9645 | Val: Loss=0.7158, F1 Score=0.8895
# Epoch  40/500 | Train: Loss=0.0365, F1 Score=0.9803 | Val: Loss=1.0685, F1 Score=0.8785
# Epoch  41/500 | Train: Loss=0.0377, F1 Score=0.9683 | Val: Loss=0.7125, F1 Score=0.8776
# Epoch  42/500 | Train: Loss=0.0220, F1 Score=0.9814 | Val: Loss=1.0678, F1 Score=0.8612
# Epoch  43/500 | Train: Loss=0.0320, F1 Score=0.9764 | Val: Loss=0.8176, F1 Score=0.9034
# Epoch  44/500 | Train: Loss=0.0225, F1 Score=0.9852 | Val: Loss=0.7601, F1 Score=0.8947
# Epoch  45/500 | Train: Loss=0.0262, F1 Score=0.9809 | Val: Loss=0.7121, F1 Score=0.9144
# Epoch  46/500 | Train: Loss=0.0287, F1 Score=0.9772 | Val: Loss=1.5134, F1 Score=0.7704
# Epoch  47/500 | Train: Loss=0.0590, F1 Score=0.9563 | Val: Loss=0.7959, F1 Score=0.8880
# Epoch  48/500 | Train: Loss=0.0323, F1 Score=0.9802 | Val: Loss=0.7450, F1 Score=0.9042
# Epoch  49/500 | Train: Loss=0.0194, F1 Score=0.9855 | Val: Loss=0.9751, F1 Score=0.8803
# Epoch  50/500 | Train: Loss=0.0205, F1 Score=0.9844 | Val: Loss=1.1180, F1 Score=0.8856
# Epoch  51/500 | Train: Loss=0.0415, F1 Score=0.9791 | Val: Loss=0.8620, F1 Score=0.8929
# Epoch  52/500 | Train: Loss=0.0509, F1 Score=0.9696 | Val: Loss=0.9494, F1 Score=0.8537
# Epoch  53/500 | Train: Loss=0.0203, F1 Score=0.9840 | Val: Loss=1.0767, F1 Score=0.8985
# Epoch  54/500 | Train: Loss=0.0532, F1 Score=0.9519 | Val: Loss=0.7656, F1 Score=0.8768
# Epoch  55/500 | Train: Loss=0.0236, F1 Score=0.9821 | Val: Loss=0.7486, F1 Score=0.8916
# Epoch  56/500 | Train: Loss=0.0215, F1 Score=0.9852 | Val: Loss=0.8181, F1 Score=0.8873
# Epoch  57/500 | Train: Loss=0.0482, F1 Score=0.9700 | Val: Loss=1.3303, F1 Score=0.8779
# Epoch  58/500 | Train: Loss=0.0217, F1 Score=0.9829 | Val: Loss=0.9278, F1 Score=0.8965
# Epoch  59/500 | Train: Loss=0.0221, F1 Score=0.9840 | Val: Loss=0.8940, F1 Score=0.8913
# Epoch  60/500 | Train: Loss=0.0201, F1 Score=0.9913 | Val: Loss=0.9710, F1 Score=0.9059
# Epoch  61/500 | Train: Loss=0.0385, F1 Score=0.9787 | Val: Loss=1.1749, F1 Score=0.8500
# Epoch  62/500 | Train: Loss=0.0335, F1 Score=0.9760 | Val: Loss=0.8658, F1 Score=0.8969
# Epoch  63/500 | Train: Loss=0.0149, F1 Score=0.9878 | Val: Loss=0.9889, F1 Score=0.8973
# Epoch  64/500 | Train: Loss=0.0263, F1 Score=0.9810 | Val: Loss=0.8593, F1 Score=0.9029
# Epoch  65/500 | Train: Loss=0.0245, F1 Score=0.9825 | Val: Loss=0.9567, F1 Score=0.8745
# Epoch  66/500 | Train: Loss=0.0193, F1 Score=0.9836 | Val: Loss=0.9007, F1 Score=0.9059
# Epoch  67/500 | Train: Loss=0.0207, F1 Score=0.9848 | Val: Loss=1.0361, F1 Score=0.9004
# Epoch  68/500 | Train: Loss=0.0351, F1 Score=0.9776 | Val: Loss=0.8094, F1 Score=0.8939
# Epoch  69/500 | Train: Loss=0.0691, F1 Score=0.9712 | Val: Loss=0.7001, F1 Score=0.9006
# Epoch  70/500 | Train: Loss=0.0159, F1 Score=0.9890 | Val: Loss=1.0319, F1 Score=0.8988
# Epoch  71/500 | Train: Loss=0.0257, F1 Score=0.9829 | Val: Loss=0.9110, F1 Score=0.8688
# Epoch  72/500 | Train: Loss=0.0299, F1 Score=0.9794 | Val: Loss=0.7013, F1 Score=0.8811
# Epoch  73/500 | Train: Loss=0.0191, F1 Score=0.9863 | Val: Loss=0.8373, F1 Score=0.9012
# Epoch  74/500 | Train: Loss=0.0095, F1 Score=0.9928 | Val: Loss=0.9401, F1 Score=0.9044
# Epoch  75/500 | Train: Loss=0.0190, F1 Score=0.9844 | Val: Loss=1.0379, F1 Score=0.9027
# Epoch  76/500 | Train: Loss=0.0451, F1 Score=0.9653 | Val: Loss=0.7238, F1 Score=0.8549
# Epoch  77/500 | Train: Loss=0.0230, F1 Score=0.9795 | Val: Loss=0.8522, F1 Score=0.8815
# Epoch  78/500 | Train: Loss=0.0244, F1 Score=0.9852 | Val: Loss=0.8148, F1 Score=0.9000
# Epoch  79/500 | Train: Loss=0.0136, F1 Score=0.9897 | Val: Loss=0.7952, F1 Score=0.9093
# Epoch  80/500 | Train: Loss=0.0355, F1 Score=0.9818 | Val: Loss=0.8815, F1 Score=0.8956
# Epoch  81/500 | Train: Loss=0.0149, F1 Score=0.9882 | Val: Loss=0.8686, F1 Score=0.9006
# Epoch  82/500 | Train: Loss=0.0112, F1 Score=0.9924 | Val: Loss=1.1331, F1 Score=0.8916
# Epoch  83/500 | Train: Loss=0.0077, F1 Score=0.9954 | Val: Loss=1.0976, F1 Score=0.9012
# Epoch  84/500 | Train: Loss=0.0079, F1 Score=0.9966 | Val: Loss=1.0745, F1 Score=0.9022
# Epoch  85/500 | Train: Loss=0.0085, F1 Score=0.9939 | Val: Loss=1.1820, F1 Score=0.8928
# Epoch  86/500 | Train: Loss=0.0073, F1 Score=0.9947 | Val: Loss=1.2498, F1 Score=0.9123
# Epoch  87/500 | Train: Loss=0.0240, F1 Score=0.9871 | Val: Loss=0.9719, F1 Score=0.8907
# Epoch  88/500 | Train: Loss=0.0439, F1 Score=0.9795 | Val: Loss=1.0984, F1 Score=0.8929
# Epoch  89/500 | Train: Loss=0.0194, F1 Score=0.9871 | Val: Loss=1.1160, F1 Score=0.8901
# Epoch  90/500 | Train: Loss=0.0103, F1 Score=0.9916 | Val: Loss=1.1022, F1 Score=0.8881
# Epoch  91/500 | Train: Loss=0.0080, F1 Score=0.9962 | Val: Loss=1.2165, F1 Score=0.8925
# Epoch  92/500 | Train: Loss=0.0084, F1 Score=0.9955 | Val: Loss=1.1251, F1 Score=0.8962
# Epoch  93/500 | Train: Loss=0.0136, F1 Score=0.9913 | Val: Loss=1.1565, F1 Score=0.8786
# Epoch  94/500 | Train: Loss=0.0085, F1 Score=0.9951 | Val: Loss=1.2689, F1 Score=0.9079
# Epoch  95/500 | Train: Loss=0.0265, F1 Score=0.9813 | Val: Loss=0.9820, F1 Score=0.8454
# Epoch  96/500 | Train: Loss=0.0219, F1 Score=0.9875 | Val: Loss=0.9672, F1 Score=0.8862
# Epoch  97/500 | Train: Loss=0.0689, F1 Score=0.9762 | Val: Loss=0.7692, F1 Score=0.8650
# Epoch  98/500 | Train: Loss=0.0221, F1 Score=0.9836 | Val: Loss=0.7727, F1 Score=0.9109
# Epoch  99/500 | Train: Loss=0.0081, F1 Score=0.9947 | Val: Loss=0.8356, F1 Score=0.9034
# Epoch 100/500 | Train: Loss=0.0067, F1 Score=0.9954 | Val: Loss=1.0370, F1 Score=0.9048
# Epoch 101/500 | Train: Loss=0.0249, F1 Score=0.9841 | Val: Loss=0.9603, F1 Score=0.9010
# Epoch 102/500 | Train: Loss=0.0118, F1 Score=0.9928 | Val: Loss=1.0395, F1 Score=0.9009
# Epoch 103/500 | Train: Loss=0.0354, F1 Score=0.9768 | Val: Loss=0.9031, F1 Score=0.8539
# Epoch 104/500 | Train: Loss=0.0330, F1 Score=0.9791 | Val: Loss=0.9060, F1 Score=0.8452
# Epoch 105/500 | Train: Loss=0.0201, F1 Score=0.9844 | Val: Loss=1.0677, F1 Score=0.8946
# Epoch 106/500 | Train: Loss=0.0271, F1 Score=0.9794 | Val: Loss=0.8645, F1 Score=0.8951
# Epoch 107/500 | Train: Loss=0.0123, F1 Score=0.9928 | Val: Loss=1.1168, F1 Score=0.8815
# Epoch 108/500 | Train: Loss=0.0139, F1 Score=0.9909 | Val: Loss=0.9227, F1 Score=0.8732
# Epoch 109/500 | Train: Loss=0.0123, F1 Score=0.9920 | Val: Loss=1.0649, F1 Score=0.9004
# Epoch 110/500 | Train: Loss=0.0125, F1 Score=0.9913 | Val: Loss=1.1338, F1 Score=0.8101
# Epoch 111/500 | Train: Loss=0.0111, F1 Score=0.9913 | Val: Loss=1.0557, F1 Score=0.9103
# Epoch 112/500 | Train: Loss=0.0062, F1 Score=0.9981 | Val: Loss=1.0601, F1 Score=0.9062
# Epoch 113/500 | Train: Loss=0.0055, F1 Score=0.9977 | Val: Loss=1.2441, F1 Score=0.9038
# Epoch 114/500 | Train: Loss=0.0040, F1 Score=0.9985 | Val: Loss=1.5392, F1 Score=0.9002
# Epoch 115/500 | Train: Loss=0.0051, F1 Score=0.9973 | Val: Loss=1.4088, F1 Score=0.9075
# Epoch 116/500 | Train: Loss=0.0065, F1 Score=0.9962 | Val: Loss=1.4594, F1 Score=0.9002
# Epoch 117/500 | Train: Loss=0.0064, F1 Score=0.9970 | Val: Loss=1.4666, F1 Score=0.8528
# Epoch 118/500 | Train: Loss=0.0283, F1 Score=0.9791 | Val: Loss=1.1813, F1 Score=0.8995
# Epoch 119/500 | Train: Loss=0.0130, F1 Score=0.9924 | Val: Loss=1.3347, F1 Score=0.9046
# Epoch 120/500 | Train: Loss=0.0214, F1 Score=0.9833 | Val: Loss=0.9541, F1 Score=0.8987
# Epoch 121/500 | Train: Loss=0.0089, F1 Score=0.9958 | Val: Loss=1.1798, F1 Score=0.9005
# Epoch 122/500 | Train: Loss=0.0528, F1 Score=0.9841 | Val: Loss=0.9027, F1 Score=0.9064
# Epoch 123/500 | Train: Loss=0.0105, F1 Score=0.9913 | Val: Loss=0.9142, F1 Score=0.8950
# Epoch 124/500 | Train: Loss=0.0157, F1 Score=0.9920 | Val: Loss=0.7518, F1 Score=0.9039
# Epoch 125/500 | Train: Loss=0.0243, F1 Score=0.9928 | Val: Loss=0.8474, F1 Score=0.9180
# Epoch 126/500 | Train: Loss=0.0203, F1 Score=0.9863 | Val: Loss=1.0905, F1 Score=0.9131
# Epoch 127/500 | Train: Loss=0.0159, F1 Score=0.9886 | Val: Loss=0.9180, F1 Score=0.8991
# Epoch 128/500 | Train: Loss=0.0168, F1 Score=0.9852 | Val: Loss=1.1293, F1 Score=0.9087
# Epoch 129/500 | Train: Loss=0.0136, F1 Score=0.9901 | Val: Loss=0.9223, F1 Score=0.9065
# Epoch 130/500 | Train: Loss=0.0102, F1 Score=0.9936 | Val: Loss=0.9927, F1 Score=0.9132
# Epoch 131/500 | Train: Loss=0.0085, F1 Score=0.9943 | Val: Loss=0.9317, F1 Score=0.9177
# Epoch 132/500 | Train: Loss=0.0160, F1 Score=0.9905 | Val: Loss=1.0146, F1 Score=0.9127
# Epoch 133/500 | Train: Loss=0.0134, F1 Score=0.9943 | Val: Loss=0.9118, F1 Score=0.9093
# Epoch 134/500 | Train: Loss=0.0081, F1 Score=0.9932 | Val: Loss=1.1555, F1 Score=0.9246
# Epoch 135/500 | Train: Loss=0.0078, F1 Score=0.9962 | Val: Loss=1.0975, F1 Score=0.9129
# Epoch 136/500 | Train: Loss=0.0056, F1 Score=0.9966 | Val: Loss=1.1007, F1 Score=0.9147
# Epoch 137/500 | Train: Loss=0.0109, F1 Score=0.9939 | Val: Loss=1.2705, F1 Score=0.9000
# Epoch 138/500 | Train: Loss=0.0052, F1 Score=0.9977 | Val: Loss=1.1606, F1 Score=0.9124
# Epoch 139/500 | Train: Loss=0.0095, F1 Score=0.9966 | Val: Loss=1.2236, F1 Score=0.9132
# Epoch 140/500 | Train: Loss=0.0101, F1 Score=0.9951 | Val: Loss=1.2628, F1 Score=0.9076
# Epoch 141/500 | Train: Loss=0.0285, F1 Score=0.9905 | Val: Loss=1.7830, F1 Score=0.8669
# Epoch 142/500 | Train: Loss=0.0359, F1 Score=0.9814 | Val: Loss=1.1045, F1 Score=0.9000
# Epoch 143/500 | Train: Loss=0.0126, F1 Score=0.9936 | Val: Loss=1.2114, F1 Score=0.9036
# Epoch 144/500 | Train: Loss=0.0063, F1 Score=0.9966 | Val: Loss=1.4189, F1 Score=0.9036
# Epoch 145/500 | Train: Loss=0.0130, F1 Score=0.9951 | Val: Loss=1.2097, F1 Score=0.9056
# Epoch 146/500 | Train: Loss=0.0126, F1 Score=0.9924 | Val: Loss=1.3387, F1 Score=0.8126
# Epoch 147/500 | Train: Loss=0.0119, F1 Score=0.9928 | Val: Loss=1.2433, F1 Score=0.9136
# Epoch 148/500 | Train: Loss=0.0220, F1 Score=0.9882 | Val: Loss=0.8592, F1 Score=0.9108
# Epoch 149/500 | Train: Loss=0.0065, F1 Score=0.9966 | Val: Loss=1.0714, F1 Score=0.9082
# Epoch 150/500 | Train: Loss=0.0098, F1 Score=0.9936 | Val: Loss=0.9780, F1 Score=0.9205
# Epoch 151/500 | Train: Loss=0.0049, F1 Score=0.9985 | Val: Loss=0.9508, F1 Score=0.9159
# Epoch 152/500 | Train: Loss=0.0039, F1 Score=0.9989 | Val: Loss=1.1624, F1 Score=0.9167
# Epoch 153/500 | Train: Loss=0.0095, F1 Score=0.9943 | Val: Loss=0.8522, F1 Score=0.9262
# Epoch 154/500 | Train: Loss=0.0237, F1 Score=0.9928 | Val: Loss=1.2129, F1 Score=0.9020
# Epoch 155/500 | Train: Loss=0.0105, F1 Score=0.9932 | Val: Loss=0.9407, F1 Score=0.9110
# Epoch 156/500 | Train: Loss=0.0109, F1 Score=0.9947 | Val: Loss=1.1152, F1 Score=0.9118
# Epoch 157/500 | Train: Loss=0.0113, F1 Score=0.9958 | Val: Loss=1.2065, F1 Score=0.8839
# Epoch 158/500 | Train: Loss=0.0171, F1 Score=0.9848 | Val: Loss=1.0312, F1 Score=0.9114
# Epoch 159/500 | Train: Loss=0.0177, F1 Score=0.9943 | Val: Loss=1.2527, F1 Score=0.9144
# Epoch 160/500 | Train: Loss=0.0132, F1 Score=0.9924 | Val: Loss=1.2470, F1 Score=0.9066
# Epoch 161/500 | Train: Loss=0.0129, F1 Score=0.9913 | Val: Loss=0.9634, F1 Score=0.8791
# Epoch 162/500 | Train: Loss=0.0184, F1 Score=0.9867 | Val: Loss=0.9816, F1 Score=0.8875
# Epoch 163/500 | Train: Loss=0.0102, F1 Score=0.9909 | Val: Loss=1.0945, F1 Score=0.9050
# Epoch 164/500 | Train: Loss=0.0075, F1 Score=0.9958 | Val: Loss=1.0956, F1 Score=0.8921
# Epoch 165/500 | Train: Loss=0.0105, F1 Score=0.9917 | Val: Loss=1.1668, F1 Score=0.9035
# Epoch 166/500 | Train: Loss=0.0216, F1 Score=0.9882 | Val: Loss=0.9418, F1 Score=0.9036
# Epoch 167/500 | Train: Loss=0.0179, F1 Score=0.9852 | Val: Loss=0.9909, F1 Score=0.9137
# Epoch 168/500 | Train: Loss=0.0055, F1 Score=0.9970 | Val: Loss=1.2065, F1 Score=0.9122
# Epoch 169/500 | Train: Loss=0.0051, F1 Score=0.9977 | Val: Loss=1.3912, F1 Score=0.9101
# Epoch 170/500 | Train: Loss=0.0083, F1 Score=0.9962 | Val: Loss=1.2018, F1 Score=0.8996
# Epoch 171/500 | Train: Loss=0.0064, F1 Score=0.9962 | Val: Loss=1.4336, F1 Score=0.9007
# Epoch 172/500 | Train: Loss=0.0115, F1 Score=0.9935 | Val: Loss=1.2873, F1 Score=0.9002
# Epoch 173/500 | Train: Loss=0.0058, F1 Score=0.9973 | Val: Loss=1.4009, F1 Score=0.8983
# Epoch 174/500 | Train: Loss=0.0058, F1 Score=0.9958 | Val: Loss=1.3083, F1 Score=0.9064
# Epoch 175/500 | Train: Loss=0.0100, F1 Score=0.9932 | Val: Loss=1.4485, F1 Score=0.8885
# Epoch 176/500 | Train: Loss=0.0049, F1 Score=0.9981 | Val: Loss=1.6472, F1 Score=0.9041
# Epoch 177/500 | Train: Loss=0.0108, F1 Score=0.9928 | Val: Loss=1.5200, F1 Score=0.9055
# Epoch 178/500 | Train: Loss=0.0111, F1 Score=0.9928 | Val: Loss=0.9321, F1 Score=0.8840
# Epoch 179/500 | Train: Loss=0.0251, F1 Score=0.9867 | Val: Loss=1.2896, F1 Score=0.8952
# Epoch 180/500 | Train: Loss=0.0193, F1 Score=0.9905 | Val: Loss=0.9306, F1 Score=0.8922
# Epoch 181/500 | Train: Loss=0.0188, F1 Score=0.9928 | Val: Loss=1.1428, F1 Score=0.9019
# Epoch 182/500 | Train: Loss=0.0099, F1 Score=0.9939 | Val: Loss=1.0509, F1 Score=0.8902
# Epoch 183/500 | Train: Loss=0.0091, F1 Score=0.9939 | Val: Loss=1.1668, F1 Score=0.9008
# Epoch 184/500 | Train: Loss=0.0098, F1 Score=0.9947 | Val: Loss=1.2693, F1 Score=0.9101
# Epoch 185/500 | Train: Loss=0.0045, F1 Score=0.9985 | Val: Loss=1.3497, F1 Score=0.9082
# Epoch 186/500 | Train: Loss=0.0041, F1 Score=0.9992 | Val: Loss=1.4073, F1 Score=0.9047
# Epoch 187/500 | Train: Loss=0.0035, F1 Score=0.9996 | Val: Loss=1.2873, F1 Score=0.9058
# Epoch 188/500 | Train: Loss=0.0116, F1 Score=0.9943 | Val: Loss=0.9388, F1 Score=0.8817
# Epoch 189/500 | Train: Loss=0.0282, F1 Score=0.9867 | Val: Loss=1.2684, F1 Score=0.9016
# Epoch 190/500 | Train: Loss=0.0214, F1 Score=0.9875 | Val: Loss=1.0428, F1 Score=0.8939
# Epoch 191/500 | Train: Loss=0.0112, F1 Score=0.9936 | Val: Loss=1.1803, F1 Score=0.9053
# Epoch 192/500 | Train: Loss=0.0096, F1 Score=0.9947 | Val: Loss=1.2546, F1 Score=0.9081
# Epoch 193/500 | Train: Loss=0.0289, F1 Score=0.9913 | Val: Loss=1.3266, F1 Score=0.9116
# Epoch 194/500 | Train: Loss=0.0096, F1 Score=0.9935 | Val: Loss=1.3526, F1 Score=0.9062
# Epoch 195/500 | Train: Loss=0.0067, F1 Score=0.9962 | Val: Loss=1.3532, F1 Score=0.9094
# Epoch 196/500 | Train: Loss=0.0053, F1 Score=0.9981 | Val: Loss=1.5332, F1 Score=0.9056
# Epoch 197/500 | Train: Loss=0.0053, F1 Score=0.9973 | Val: Loss=1.2671, F1 Score=0.8841
# Epoch 198/500 | Train: Loss=0.0097, F1 Score=0.9932 | Val: Loss=1.6396, F1 Score=0.9135
# Epoch 199/500 | Train: Loss=0.0125, F1 Score=0.9936 | Val: Loss=1.4766, F1 Score=0.9130
# Epoch 200/500 | Train: Loss=0.0103, F1 Score=0.9928 | Val: Loss=1.1768, F1 Score=0.9102
# Epoch 201/500 | Train: Loss=0.0078, F1 Score=0.9970 | Val: Loss=1.2129, F1 Score=0.9077
# Epoch 202/500 | Train: Loss=0.0046, F1 Score=0.9981 | Val: Loss=1.4667, F1 Score=0.9139
# Epoch 203/500 | Train: Loss=0.0034, F1 Score=1.0000 | Val: Loss=1.5051, F1 Score=0.9051
# Epoch 204/500 | Train: Loss=0.0041, F1 Score=0.9989 | Val: Loss=1.6635, F1 Score=0.9130
# Epoch 205/500 | Train: Loss=0.0130, F1 Score=0.9973 | Val: Loss=1.3653, F1 Score=0.8996
# Epoch 206/500 | Train: Loss=0.0064, F1 Score=0.9966 | Val: Loss=1.5276, F1 Score=0.8902
# Epoch 207/500 | Train: Loss=0.0387, F1 Score=0.9867 | Val: Loss=1.7015, F1 Score=0.8106
# Epoch 208/500 | Train: Loss=0.0133, F1 Score=0.9897 | Val: Loss=1.3558, F1 Score=0.8980
# Epoch 209/500 | Train: Loss=0.0060, F1 Score=0.9966 | Val: Loss=1.5561, F1 Score=0.8992
# Epoch 210/500 | Train: Loss=0.0088, F1 Score=0.9932 | Val: Loss=1.6157, F1 Score=0.9059
# Epoch 211/500 | Train: Loss=0.0070, F1 Score=0.9947 | Val: Loss=1.6956, F1 Score=0.8996
# Epoch 212/500 | Train: Loss=0.0214, F1 Score=0.9943 | Val: Loss=1.2843, F1 Score=0.8924
# Epoch 213/500 | Train: Loss=0.0100, F1 Score=0.9943 | Val: Loss=1.4243, F1 Score=0.8626
# Epoch 214/500 | Train: Loss=0.0077, F1 Score=0.9943 | Val: Loss=1.5535, F1 Score=0.8982
# Epoch 215/500 | Train: Loss=0.0093, F1 Score=0.9939 | Val: Loss=1.8203, F1 Score=0.9043
# Epoch 216/500 | Train: Loss=0.0140, F1 Score=0.9951 | Val: Loss=1.3320, F1 Score=0.9029
# Epoch 217/500 | Train: Loss=0.0085, F1 Score=0.9977 | Val: Loss=1.9480, F1 Score=0.8979
# Epoch 218/500 | Train: Loss=0.0056, F1 Score=0.9992 | Val: Loss=1.6987, F1 Score=0.9086
# Epoch 219/500 | Train: Loss=0.0073, F1 Score=0.9955 | Val: Loss=1.9303, F1 Score=0.9180
# Epoch 220/500 | Train: Loss=0.0112, F1 Score=0.9932 | Val: Loss=1.8502, F1 Score=0.9096
# Epoch 221/500 | Train: Loss=0.0053, F1 Score=0.9981 | Val: Loss=1.8695, F1 Score=0.9126
# Epoch 222/500 | Train: Loss=0.0065, F1 Score=0.9973 | Val: Loss=1.6730, F1 Score=0.9072
# Epoch 223/500 | Train: Loss=0.0074, F1 Score=0.9954 | Val: Loss=1.3133, F1 Score=0.9050
# Epoch 224/500 | Train: Loss=0.0073, F1 Score=0.9958 | Val: Loss=1.7652, F1 Score=0.9163
# Epoch 225/500 | Train: Loss=0.0047, F1 Score=0.9985 | Val: Loss=1.7489, F1 Score=0.9077
# Epoch 226/500 | Train: Loss=0.0077, F1 Score=0.9973 | Val: Loss=1.7495, F1 Score=0.8979
# Epoch 227/500 | Train: Loss=0.0116, F1 Score=0.9962 | Val: Loss=1.4680, F1 Score=0.8876
# Epoch 228/500 | Train: Loss=0.0126, F1 Score=0.9879 | Val: Loss=1.1391, F1 Score=0.8989
# Epoch 229/500 | Train: Loss=0.0060, F1 Score=0.9966 | Val: Loss=1.5044, F1 Score=0.9063
# Epoch 230/500 | Train: Loss=0.0095, F1 Score=0.9943 | Val: Loss=1.6168, F1 Score=0.9048
# Epoch 231/500 | Train: Loss=0.0101, F1 Score=0.9936 | Val: Loss=1.3908, F1 Score=0.9043
# Epoch 232/500 | Train: Loss=0.0059, F1 Score=0.9977 | Val: Loss=1.6981, F1 Score=0.9147
# Epoch 233/500 | Train: Loss=0.0038, F1 Score=0.9996 | Val: Loss=1.7041, F1 Score=0.8956
# Epoch 234/500 | Train: Loss=0.0083, F1 Score=0.9939 | Val: Loss=1.9074, F1 Score=0.8873
# Epoch 235/500 | Train: Loss=0.0118, F1 Score=0.9932 | Val: Loss=1.5040, F1 Score=0.9141
# Epoch 236/500 | Train: Loss=0.0075, F1 Score=0.9977 | Val: Loss=1.6118, F1 Score=0.9078
# Epoch 237/500 | Train: Loss=0.0078, F1 Score=0.9962 | Val: Loss=1.0995, F1 Score=0.8909
# Epoch 238/500 | Train: Loss=0.0171, F1 Score=0.9909 | Val: Loss=1.6733, F1 Score=0.9029
# Epoch 239/500 | Train: Loss=0.0208, F1 Score=0.9913 | Val: Loss=1.3393, F1 Score=0.9048
# Epoch 240/500 | Train: Loss=0.0152, F1 Score=0.9951 | Val: Loss=1.5035, F1 Score=0.9080
# Epoch 241/500 | Train: Loss=0.0141, F1 Score=0.9913 | Val: Loss=1.4712, F1 Score=0.9059
# Epoch 242/500 | Train: Loss=0.0060, F1 Score=0.9958 | Val: Loss=1.6719, F1 Score=0.9136
# Epoch 243/500 | Train: Loss=0.0046, F1 Score=0.9996 | Val: Loss=1.7731, F1 Score=0.9168
# Epoch 244/500 | Train: Loss=0.0099, F1 Score=0.9939 | Val: Loss=1.6733, F1 Score=0.9122
# Epoch 245/500 | Train: Loss=0.0044, F1 Score=0.9989 | Val: Loss=1.7126, F1 Score=0.9165
# Epoch 246/500 | Train: Loss=0.0034, F1 Score=0.9996 | Val: Loss=1.7788, F1 Score=0.9159
# Epoch 247/500 | Train: Loss=0.0047, F1 Score=0.9977 | Val: Loss=1.8852, F1 Score=0.9127
# Epoch 248/500 | Train: Loss=0.0061, F1 Score=0.9962 | Val: Loss=1.7346, F1 Score=0.9111
# Epoch 249/500 | Train: Loss=0.0054, F1 Score=0.9977 | Val: Loss=1.8787, F1 Score=0.8864
# Epoch 250/500 | Train: Loss=0.0129, F1 Score=0.9924 | Val: Loss=1.6958, F1 Score=0.9121
# Epoch 251/500 | Train: Loss=0.0225, F1 Score=0.9936 | Val: Loss=1.8370, F1 Score=0.8903
# Epoch 252/500 | Train: Loss=0.0182, F1 Score=0.9955 | Val: Loss=1.5387, F1 Score=0.9159
# Epoch 253/500 | Train: Loss=0.0059, F1 Score=0.9981 | Val: Loss=1.7363, F1 Score=0.9070
# Early stopping triggered after 253 epochs.
# Best model restored from epoch 153 with val_f1 0.9262

# %%
# @title
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# @title
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader:
        # Move data to device and convert to float32
        xb = xb.to(device).float()

        # Forward pass: get model predictions
        logits = model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.9248
# Precision over the validation set: 0.9281
# Recall over the validation set: 0.9248
# F1 score over the validation set: 0.9262

# %% [markdown]
# ## Submission

# %%
model = CNN_GRU_Classifier(
    input_size=input_size,
    num_classes=num_classes,
    hidden_size=best_params["hidden_size"],
    num_layers=best_params["num_layers"],
    dropout_rate=best_params["dropout_rate"],
    bidirectional=False,
    use_attention=True
).to(device)

model_path = BASE_PATH+"models/"+"cnn_gru_nobi_optuna_model.pt"

rnn_model.load_state_dict(torch.load(model_path, map_location=device))
rnn_model.to(device)
rnn_model.eval()
# Out:
# CNN_GRU_Classifier(
#   (cnn): Sequential(
#     (0): Conv1d(34, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (4): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Dropout(p=0.0, inplace=False)
#   )
#   (gru): GRU(128, 128, num_layers=2, batch_first=True)
#   (attention): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=1, bias=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=128, out_features=3, bias=True)
#   )
# )

# %%
# Check loaded model performance
val_loss, val_f1 = validate_one_epoch(rnn_model, val_loader, criterion, device)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation F1:   {val_f1:.4f}")
# Out:
# Validation Loss: 0.8522
# Validation F1:   0.9262

# %%
num_joints = 29
scale_columns = [f'joint_{i:02d}' for i in range(num_joints+1)]

mins = X_test[scale_columns].min()
maxs = X_test[scale_columns].max()

for column in scale_columns:
    X_test[column] = (X_test[column] - mins[column]) / (maxs[column] - mins[column])

X_test_seq = build_sequences(X_test, best_params["window_size"], best_params["stride"], is_test=True)

X_test_tensor = torch.from_numpy(X_test_seq).float()
test_ds  = TensorDataset(X_test_tensor)

test_loader  = make_loader(test_ds, batch_size= best_params["batch_size"], shuffle=False, drop_last=False)

preds = []
with torch.no_grad():
    for (xb,) in test_loader:
        xb = xb.to(device).float()
        logits = model(xb)
        batch_preds  = torch.argmax(logits, 1)
        preds.extend(batch_preds.cpu().numpy())

preds = np.array(preds)
print("Tot preds:", len(preds))
unique, counts = np.unique(preds, return_counts=True)
print("Distribution:", dict(zip(unique, counts)))
# Out:
# Tot preds: 6620
# Distribution: {np.int64(0): np.int64(2157), np.int64(1): np.int64(5), np.int64(2): np.int64(4458)}

# %%
def build_sequences_test(df, window_size, stride):
    """Create temporal windows for the test set from a time-series DataFrame.

    Args:
        df (pd.DataFrame): DataFrame with the 'sample_index' and 'time' columns plus numeric features.
        window_size (int): number of timesteps per window.
        stride (int): step by which the window advances.

    Returns:
        tuple:
            X_seq (np.ndarray): input sequences of shape (n_windows, window_size, n_features)
            seq_indices (np.ndarray): sample_index associated with each window
    """

    feature_cols = [col for col in df.columns if col not in ["sample_index", "time"]]
    X_seq = []
    seq_indices = []

    # Iterate over each subject / sequence
    for sid, group in df.groupby("sample_index"):
        group = group.sort_values("time")
        values = group[feature_cols].values
        n_time = len(values)

        # Create sliding windows
        for start in range(0, n_time - window_size + 1, stride):
            end = start + window_size
            window = values[start:end]
            X_seq.append(window)
            seq_indices.append(sid)

    X_seq = np.stack(X_seq)
    seq_indices = np.array(seq_indices)

    print(f"Created {len(X_seq)} windows from {df['sample_index'].nunique()} samples "
          f"(window={window_size}, stride={stride})")

    return X_seq, seq_indices

X_test_seq, test_indices = build_sequences_test(X_test,
    best_params["window_size"],
    best_params["stride"]
)

X_test_tensor = torch.from_numpy(X_test_seq).float()
test_ds = TensorDataset(X_test_tensor)
test_loader = make_loader(
    test_ds,
    batch_size=best_params["batch_size"],
    shuffle=False,
    drop_last=False
)

preds = []
with torch.no_grad():
    for (xb,) in test_loader:
        xb = xb.to(device).float()
        logits = model(xb)
        batch_preds  = torch.argmax(logits, 1)
        preds.extend(batch_preds.cpu().numpy())

window_df = pd.DataFrame({
    "sample_index": test_indices,
    "pred": preds
})

final_preds = (
    window_df.groupby("sample_index")["pred"]
    .agg(lambda x: np.bincount(x).argmax())   # moda
    .reindex(sorted(X_test["sample_index"].unique()))
)

preds = np.array(final_preds)
print("Tot preds:", len(preds))
unique, counts = np.unique(final_preds, return_counts=True)
print("Distribution:", dict(zip(unique, counts)))
# Out:
#  Created 3972 windows from 1324 samples (window=100, stride=25)
# [Note added when preparing this repository] This cell ended with RuntimeError during the original Colab run. The traceback was removed for readability; the surrounding cells show the results that were kept.

# %%
label_map   = {0: "no_pain", 1: "low_pain", 2: "high_pain"}
pred_labels = [label_map[int(p)] for p in preds]

# %%
import datetime as dt

sample_submission = pd.read_csv("../Dataset/sample_submission.csv")

submission = sample_submission.copy()
submission["label"] = pred_labels

ts = dt.datetime.now().strftime("%Y%m%d_%H%M%S")
submission.to_csv("submission.csv", index=False)
submission.to_csv(f"submission_{ts}.csv", index=False)

display(submission.head())
# Out:
#    sample_index    label
# 0             0  no_pain
# 1             1  no_pain
# 2             2  no_pain
# 3             3  no_pain
# 4             4  no_pain
