# %% [markdown]
# # Experiment — LSTM + attention with focal loss (discarded)
#
# `LSTMAttentionBinary` trained with a custom `FocalLoss`, the idea being that focal loss would help on the strongly under-represented `high_pain` class.
#
# It did not: on a dataset this small focal loss amplified label noise and destabilised optimisation. The final models use class-weighted cross-entropy with label smoothing instead. This is the experiment described in section 4 of the report.
#
# ---

# %% [markdown]
# ## Google Drive Connection

# %%
# --- Paths ---------------------------------------------------------------
# Originally executed on Google Colab with the dataset on Google Drive.
# DATA_DIR must contain: pirate_pain_train.csv, pirate_pain_train_labels.csv,
# pirate_pain_test.csv, sample_submission.csv  (see data/README.md)
import os

DATA_DIR = os.environ.get("PIRATE_DATA_DIR", "data")
os.makedirs("models", exist_ok=True)
os.makedirs("artifacts", exist_ok=True)

# %% [markdown]
# ## Libraries Import

# %%
# @title
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
# from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, Dataset, DataLoader, WeightedRandomSampler
logs_dir = "tensorboard"
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

from sklearn.model_selection import StratifiedGroupKFold

import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from torch.cuda.amp import GradScaler
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
# Out:
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# ## Exploration and Data Analysis

# %%
# Define the window size
WINDOW_SIZE = 200

# Define the stride for overlapping windows
STRIDE = 50

# Define the batch size
BATCH_SIZE = 64

KFOLD_SPLITS = 3

# %%
X_train = pd.read_csv('../Dataset/pirate_pain_train.csv')
y_train = pd.read_csv('../Dataset/pirate_pain_train_labels.csv')
X_test = pd.read_csv('../Dataset/pirate_pain_test.csv')

# Remove rows with any missing values
X_train.dropna(axis=0, how='any', inplace=True)
y_train.dropna(axis=0, how='any', inplace=True)
X_test.dropna(axis=0, how='any', inplace=True)

df_full = X_train.merge(y_train, on="sample_index")
df_full = df_full[df_full["label"] != "no_pain"]
X_train = df_full.drop(columns=["label"])
y_train = df_full[["sample_index", "label"]]

# Check for and drop columns with only one unique value
cols_to_drop = []
for col in X_train.columns:
  if X_train[col].nunique() == 1:
    print(f"Column '{col}' has only one unique value")
    cols_to_drop.append(col)

X_train = X_train.drop(columns=cols_to_drop)

# Check unique values in 'n_legs', 'n_hands', and 'n_eyes'
print("Unique values in 'n_legs':", X_train['n_legs'].unique())
print("Unique values in 'n_hands':", X_train['n_hands'].unique())
print("Unique values in 'n_eyes':", X_train['n_eyes'].unique())

# Define a mapping for string representations of strings to integers
legs_mapping = {
    'two': 2,
    'one+peg_leg': 1
}

hands_mapping = {
    'two': 2,
    'one+hook_hand': 1
}

eyes_mapping = {
    'two': 2,
    'one+eye_patch': 1
}

# Convert 'n_legs', 'n_hands', and 'n_eyes' to integers using the mapping
X_train['n_legs'] = X_train['n_legs'].map(legs_mapping)
X_train['n_hands'] = X_train['n_hands'].map(hands_mapping)
X_train['n_eyes'] = X_train['n_eyes'].map(eyes_mapping)

X_test['n_legs'] = X_test['n_legs'].map(legs_mapping)
X_test['n_hands'] = X_test['n_hands'].map(hands_mapping)
X_test['n_eyes'] = X_test['n_eyes'].map(eyes_mapping)

# Define a mapping of status names to integer labels
label_mapping = {
    'low_pain': 0,
    'high_pain': 1
}

# Map status names to integers in the labels set
y_train['label'] = y_train['label'].map(label_mapping)

# Convert 'joint_*' columns to float32 data type to use less memory
for col in X_train.columns:
  if 'joint' in col:
    X_train[col] = X_train[col].astype(np.float32)

for col in X_test.columns:
  if 'joint' in col:
    X_test[col] = X_test[col].astype(np.float32)

# StratifiedGroup Split
df_subjects = (X_train[['sample_index']]
    .drop_duplicates()
    .merge(y_train, on='sample_index')
)

sgkf = StratifiedGroupKFold(n_splits=KFOLD_SPLITS, shuffle=True, random_state=SEED)
train_idx, val_idx = next(sgkf.split(
    df_subjects,
    df_subjects['label'],
    groups=df_subjects['sample_index']
))

train_users = df_subjects.iloc[train_idx]['sample_index'].values
val_users   = df_subjects.iloc[val_idx]['sample_index'].values

df_train = X_train[X_train['sample_index'].isin(train_users)]
df_val   = X_train[X_train['sample_index'].isin(val_users)]

# Define the columns to be normalised
num_joints = 29
pain_survey_cols = [f'pain_survey_{i+1}' for i in range(4)]
joint_cols = [f'joint_{i:02d}' for i in range(num_joints + 1)]
dyn_cols = pain_survey_cols + joint_cols

means = df_train[dyn_cols].mean()
stds  = df_train[dyn_cols].std()

# Z-score normalization
for df in [df_train, df_val]:
    df[dyn_cols] = (df[dyn_cols] - means) / (stds + 1e-8)
# Out:
# Column 'joint_30' has only one unique value
# Unique values in 'n_legs': ['two' 'one+peg_leg']
# Unique values in 'n_hands': ['two' 'one+hook_hand']
# Unique values in 'n_eyes': ['two' 'one+eye_patch']

# %%
import numpy as np

def augment_sequence(X_seq,
                     noise_std=0.01,
                     scale_sigma=0.05,
                     time_warp_sigma=0.05,
                     jitter_prob=0.05,
                     slice_ratio=0.9):
    """Data augmentation for multivariate time series (pirate joints + pain_survey).

    Args:
        X_seq (np.ndarray): Sequence (window, features)
        noise_std (float): Gaussian noise applied to joints
        scale_sigma (float): Magnitude scaling factor
        time_warp_sigma (float): Amount of time warping
        jitter_prob (float): Probability of adding noise per element
        slice_ratio (float): Fraction of the sequence to keep

    Returns:
        np.ndarray: Augmented sequence (window, features)
    """X_aug = X_seq.copy()
    window, n_features = X_aug.shape

    # Define columns
    pain_survey_cols = 4          # first 4 features are pain_survey
    joint_cols = n_features - pain_survey_cols

    # ------------------
    # Additive Gaussian Noise (joints only)
    # ------------------
    X_aug[:, pain_survey_cols:] += np.random.normal(0, noise_std, (window, joint_cols))

    # ------------------
    # Magnitude scaling (joints only)
    # ------------------
    factor = np.random.normal(1.0, scale_sigma)
    X_aug[:, pain_survey_cols:] *= factor

    # ------------------
    # Time warping (same for all features)
    # ------------------
    if time_warp_sigma > 0:
        tt = np.arange(window)
        tt_new = tt + np.random.normal(0, time_warp_sigma * window, size=window)
        tt_new = np.clip(tt_new, 0, window - 1)
        for i in range(n_features):
            X_aug[:, i] = np.interp(tt, tt_new, X_aug[:, i])

    # ------------------
    # Realistic jitter (joints only)
    # ------------------
    mask = np.random.rand(window, joint_cols) < jitter_prob
    X_aug[:, pain_survey_cols:][mask] += np.random.normal(0, noise_std, np.sum(mask))

    # ------------------
    # Random window slicing
    # ------------------
    if slice_ratio < 1.0:
        new_len = int(window * slice_ratio)
        start_idx = np.random.randint(0, window - new_len + 1)
        X_aug = X_aug[start_idx:start_idx + new_len]
        # Pad back to original length using edge values
        if new_len < window:
            pad_len = window - new_len
            X_aug = np.pad(X_aug, ((0, pad_len), (0, 0)), mode='edge')

    return X_aug.astype('float32')

# %%
def build_sequences(df, y_df=None, window=WINDOW_SIZE, stride=STRIDE,
                    is_test=False, augment=False):
    """Build sequences for model training/validation/test with optional augmentation.

    Args:
        df (pd.DataFrame): Input dataframe with dynamic and static features
        y_df (pd.DataFrame, optional): Labels dataframe (None if test set)
        window (int): Sequence length
        stride (int): Step size between windows
        is_test (bool): Whether building sequences for test set (no labels)
        augment (bool): Apply augmentation to dynamic features (train only)

    Returns:
        If is_test=False:
            X_seq (np.ndarray): Dynamic features, shape (num_sequences, window, n_dyn_features)
            X_static (np.ndarray): Static features, shape (num_sequences, n_static_features)
            y_seq (np.ndarray): Labels, shape (num_sequences,)
        If is_test=True:
            X_seq, X_static
    """
    num_joints = 29
    pain_survey_cols = [f'pain_survey_{i+1}' for i in range(4)]
    joint_cols = [f'joint_{i:02d}' for i in range(num_joints + 1)]
    dyn_cols = pain_survey_cols + joint_cols
    static_cols = ['n_legs','n_hands','n_eyes']

    X_seq, X_static, y_seq = [], [], []

    for sid in df['sample_index'].unique():
        temp = df[df['sample_index'] == sid]
        static_vals = temp[static_cols].iloc[0].values.astype('float32')
        dyn_vals = temp[dyn_cols].values.astype('float32')

        # Pad sequence using edge values
        pad_len = (window - len(dyn_vals) % window) % window
        if pad_len > 0:
            dyn_vals = np.pad(dyn_vals, ((0, pad_len), (0, 0)), mode='edge')

        idx = 0
        while idx + window <= len(dyn_vals):
            seq_window = dyn_vals[idx:idx + window]

            # Apply augmentation only on training data
            if augment and not is_test:
                seq_window = augment_sequence(seq_window)

            X_seq.append(seq_window)
            X_static.append(static_vals)

            if not is_test:
                label = y_df[y_df['sample_index'] == sid]['label'].values[0]
                y_seq.append(label)

            idx += stride

    X_seq = np.array(X_seq, dtype='float32')
    X_static = np.array(X_static, dtype='float32')
    y_seq = np.array(y_seq, dtype='int64') if not is_test else None

    if is_test:
        return X_seq, X_static
    return X_seq, X_static, y_seq

# %%
X_train_seq, X_train_static, y_train_seq = build_sequences(df_train, y_train, augment=True)
X_val_seq, X_val_static, y_val_seq = build_sequences(df_val, y_train, augment=False)

# Print the shapes of the generated datasets and their labels
X_train_seq.shape, y_train_seq.shape, X_val_seq.shape, y_val_seq.shape
# Out:
# ((100, 200, 34), (100,), (50, 200, 34), (50,))

# %%
# Define the input shape based on the training data
input_shape = X_train_seq.shape[1:]

# Define the number of classes based on the categorical labels
num_classes = len(np.unique(y_train_seq))

input_shape, num_classes
# Out:
# ((200, 34), 2)

# %%
class PirateDataset(Dataset):
    def __init__(self, X_seq, X_static, y=None):
        self.X_seq = torch.from_numpy(X_seq).float()
        self.X_static = torch.from_numpy(X_static).float()
        self.y = torch.from_numpy(y).long() if y is not None else None

    def __len__(self):
        return len(self.X_seq)

    def __getitem__(self, idx):
        if self.y is not None:
            return self.X_seq[idx], self.X_static[idx], self.y[idx]
        return self.X_seq[idx], self.X_static[idx]

train_ds = PirateDataset(X_train_seq, X_train_static, y_train_seq)
val_ds = PirateDataset(X_val_seq, X_val_static, y_val_seq)

# %%
def make_loader(ds, batch_size, shuffle=True, drop_last=False):
    """Create a DataLoader tuned for the Pirate Pain dataset,
    with support for static features and class balancing.
    """
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    if hasattr(ds, "y") and ds.y is not None:
        dataset_labels = ds.y.numpy()
    elif hasattr(ds, "tensors") and len(ds.tensors) > 1:
        dataset_labels = ds.tensors[1].numpy()
    else:
        dataset_labels = None

    sampler = None
    if dataset_labels is not None and shuffle:
        class_counts = np.bincount(dataset_labels)
        class_weights = 1.0 / (class_counts + 1e-9)
        sample_weights = class_weights[dataset_labels]
        sampler = WeightedRandomSampler(
            weights=sample_weights,
            num_samples=len(sample_weights),
            replacement=True
        )
        shuffle = False  # Shuffle handled by sampler

    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,
        sampler=sampler
    )

# %%
# Create data loaders with different settings for each phase
train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader   = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
# Get one batch from the training data loader
for xb, x_staticb, yb in train_loader:
    print("Dynamic features batch shape:", xb.shape)
    print("Static features batch shape:", x_staticb.shape)
    print("Labels batch shape:", yb.shape)
    break
# Out:
# Dynamic features batch shape: torch.Size([64, 200, 34])
# Static features batch shape: torch.Size([64, 3])
# Labels batch shape: torch.Size([64])

# %% [markdown]
# ## Data Preprocessing

# %%
# Define the window size
WINDOW_SIZE = 200

# Define the stride for overlapping windows
STRIDE = 50

# Define the batch size
BATCH_SIZE = 64

# %%
# -----------------------
# Load datasets
# -----------------------
X_train = pd.read_csv('../Dataset/pirate_pain_train.csv')
y_train = pd.read_csv('../Dataset/pirate_pain_train_labels.csv')
X_test  = pd.read_csv('../Dataset/pirate_pain_test.csv')

# -----------------------
# Drop missing values
# -----------------------
X_train.dropna(inplace=True)
y_train.dropna(inplace=True)
X_test.dropna(inplace=True)

# -----------------------
# Map static features to integers
# -----------------------
legs_mapping  = {'two': 2, 'one+peg_leg': 1}
hands_mapping = {'two': 2, 'one+hook_hand': 1}
eyes_mapping  = {'two': 2, 'one+eye_patch': 1}

for df in [X_train, X_test]:
    df['n_legs']  = df['n_legs'].map(legs_mapping)
    df['n_hands'] = df['n_hands'].map(hands_mapping)
    df['n_eyes']  = df['n_eyes'].map(eyes_mapping)

# -----------------------
# Merge labels and filter only low/high pain
# -----------------------
df_full = X_train.merge(y_train, on='sample_index')
df_full = df_full[df_full['label'].isin(['low_pain','high_pain'])]

X_train = df_full.drop(columns=['label'])
y_train = df_full[['sample_index','label']]

# -----------------------
# Drop columns with only one unique value
# -----------------------
cols_to_drop = [col for col in X_train.columns if X_train[col].nunique() == 1]
X_train.drop(columns=cols_to_drop, inplace=True)

# -----------------------
# Map labels to integers
# -----------------------
label_mapping = {'low_pain': 0, 'high_pain': 1}
y_train['label'] = y_train['label'].map(label_mapping)

# -----------------------
# Convert joint columns to float32
# -----------------------
num_joints = 29
joint_cols = [f'joint_{i:02d}' for i in range(num_joints+1)]
for col in joint_cols:
    X_train[col] = X_train[col].astype(np.float32)
    X_test[col]  = X_test[col].astype(np.float32)

# -----------------------
# StratifiedGroupKFold split
# -----------------------
df_subjects = X_train[['sample_index']].drop_duplicates().merge(y_train, on='sample_index')
sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
train_idx, val_idx = next(sgkf.split(df_subjects, df_subjects['label'], groups=df_subjects['sample_index']))

train_users = df_subjects.iloc[train_idx]['sample_index'].values
val_users   = df_subjects.iloc[val_idx]['sample_index'].values

df_train = X_train[X_train['sample_index'].isin(train_users)]
df_val   = X_train[X_train['sample_index'].isin(val_users)]

# -----------------------
# Z-score normalization on dynamic features
# -----------------------
pain_survey_cols = [f'pain_survey_{i+1}' for i in range(4)]
dyn_cols = pain_survey_cols + joint_cols

means = df_train[dyn_cols].mean()
stds  = df_train[dyn_cols].std()

for df in [df_train, df_val]:
    df[dyn_cols] = (df[dyn_cols] - means) / (stds + 1e-8)

# -----------------------
# Data augmentation function
# -----------------------
def augment_sequence(X_seq,
                     noise_std=0.01,
                     scale_sigma=0.05,
                     time_warp_sigma=0.05,
                     jitter_prob=0.05,
                     slice_ratio=0.9):
    X_aug = X_seq.copy()
    window, n_features = X_aug.shape
    pain_cols = 4
    joint_cols = n_features - pain_cols

    # Gaussian noise on joints
    X_aug[:, pain_cols:] += np.random.normal(0, noise_std, (window, joint_cols))
    # Magnitude scaling on joints
    factor = np.random.normal(1.0, scale_sigma)
    X_aug[:, pain_cols:] *= factor
    # Time warping
    if time_warp_sigma > 0:
        tt = np.arange(window)
        tt_new = tt + np.random.normal(0, time_warp_sigma * window, size=window)
        tt_new = np.clip(tt_new, 0, window-1)
        for i in range(n_features):
            X_aug[:, i] = np.interp(tt, tt_new, X_aug[:, i])
    # Jitter on joints
    mask = np.random.rand(window, joint_cols) < jitter_prob
    X_aug[:, pain_cols:][mask] += np.random.normal(0, noise_std, np.sum(mask))
    # Random slicing
    if slice_ratio < 1.0:
        new_len = int(window * slice_ratio)
        start_idx = np.random.randint(0, window - new_len + 1)
        X_aug = X_aug[start_idx:start_idx + new_len]
        if new_len < window:
            pad_len = window - new_len
            X_aug = np.pad(X_aug, ((0,pad_len),(0,0)), mode='edge')
    return X_aug.astype('float32')

# -----------------------
# Build sequences function
# -----------------------
def build_sequences(df, y_df=None, window=WINDOW_SIZE, stride=STRIDE, is_test=False, augment=False):
    static_cols = ['n_legs','n_hands','n_eyes']
    dyn_cols = pain_survey_cols + joint_cols
    X_seq, X_static, y_seq = [], [], []

    for sid in df['sample_index'].unique():
        temp = df[df['sample_index']==sid]
        static_vals = temp[static_cols].iloc[0].values.astype('float32')
        dyn_vals = temp[dyn_cols].values.astype('float32')

        pad_len = (window - len(dyn_vals) % window) % window
        if pad_len > 0:
            dyn_vals = np.pad(dyn_vals, ((0,pad_len),(0,0)), mode='edge')

        idx = 0
        while idx + window <= len(dyn_vals):
            seq_window = dyn_vals[idx:idx+window]
            if augment and not is_test:
                seq_window = augment_sequence(seq_window)
            X_seq.append(seq_window)
            X_static.append(static_vals)
            if not is_test:
                label = y_df[y_df['sample_index']==sid]['label'].values[0]
                y_seq.append(label)
            idx += stride

    X_seq = np.array(X_seq, dtype='float32')
    X_static = np.array(X_static, dtype='float32')
    y_seq = np.array(y_seq, dtype='int64') if not is_test else None
    return (X_seq, X_static, y_seq) if not is_test else (X_seq, X_static)

# -----------------------
# Create sequences
# -----------------------
X_train_seq, X_train_static, y_train_seq = build_sequences(df_train, y_train, augment=True)
X_val_seq, X_val_static, y_val_seq     = build_sequences(df_val, y_train, augment=False)

# -----------------------
# PyTorch Dataset
# -----------------------
class PirateDataset(Dataset):
    def __init__(self, X_seq, X_static, y=None):
        self.X_seq = torch.from_numpy(X_seq).float()
        self.X_static = torch.from_numpy(X_static).float()
        self.y = torch.from_numpy(y).long() if y is not None else None
    def __len__(self):
        return len(self.X_seq)
    def __getitem__(self, idx):
        return (self.X_seq[idx], self.X_static[idx], self.y[idx]) if self.y is not None else (self.X_seq[idx], self.X_static[idx])

# -----------------------
# DataLoader with weighted sampler
# -----------------------
def make_loader(ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False):
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    sampler = None
    if hasattr(ds,"y") and ds.y is not None and shuffle:
        labels = ds.y.numpy()
        class_counts = np.bincount(labels)
        class_weights = 1.0 / (class_counts + 1e-9)
        sample_weights = class_weights[labels]
        sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
        shuffle=False

    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last,
                      num_workers=num_workers, pin_memory=True, sampler=sampler)

# -----------------------
# Create loaders
# -----------------------
train_ds = PirateDataset(X_train_seq, X_train_static, y_train_seq)
val_ds   = PirateDataset(X_val_seq, X_val_static, y_val_seq)

train_loader = make_loader(train_ds, shuffle=True)
val_loader   = make_loader(val_ds, shuffle=False)

# %% [markdown]
# ## Model Building

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LSTMAttentionBinary(nn.Module):
    def __init__(self, seq_input_dim, static_input_dim, hidden_size=128, n_layers=2, dropout=0.3, bidirectional=True):
        super().__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1

        # LSTM over the dynamic sequences
        self.lstm = nn.LSTM(
            input_size=seq_input_dim,
            hidden_size=hidden_size,
            num_layers=n_layers,
            batch_first=True,
            dropout=dropout if n_layers>1 else 0,
            bidirectional=bidirectional
        )

        # Attention
        self.attn_fc = nn.Linear(hidden_size*self.num_directions, 1)

        # MLP static features
        self.static_fc = nn.Sequential(
            nn.Linear(static_input_dim, hidden_size),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        # Final classifier
        self.classifier = nn.Sequential(
            nn.Linear(hidden_size*self.num_directions + hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, x_seq, x_static):
        # x_seq: (batch, seq_len, features)
        lstm_out, _ = self.lstm(x_seq)  # (batch, seq_len, hidden*directions)

        # Attention
        attn_weights = torch.softmax(self.attn_fc(lstm_out), dim=1)  # (batch, seq_len, 1)
        context = torch.sum(attn_weights * lstm_out, dim=1)  # (batch, hidden*directions)

        # Static features
        static_emb = self.static_fc(x_static)  # (batch, hidden)

        # Concatenate and classify
        combined = torch.cat([context, static_emb], dim=1)
        out = self.classifier(combined)  # (batch, 1)
        return out.squeeze(1)  # (batch,)

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        bce_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-bce_loss)
        loss = self.alpha * (1-pt)**self.gamma * bce_loss
        if self.reduction=='mean':
            return loss.mean()
        elif self.reduction=='sum':
            return loss.sum()
        else:
            return loss

# %% [markdown]
# ## Training Functions

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0):
    """Perform one training epoch including static features and L1 regularization.
    """
    model.train()
    running_loss = 0.0
    all_predictions, all_targets = [], []

    for inputs, x_static, targets in train_loader:
        inputs = inputs.to(device).float()
        x_static = x_static.to(device).float()
        targets = targets.to(device).float()

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast(device_type=device.type, enabled=(device.type=='cuda')):
            logits = model(inputs, x_static)
            loss = criterion(logits, targets)

            # L1 regularization
            if l1_lambda > 0:
                l1_norm = sum(p.abs().sum() for p in model.parameters())
                loss += l1_lambda * l1_norm

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * inputs.size(0)
        all_predictions.append((logits > 0.5).long().cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(np.concatenate(all_targets), np.concatenate(all_predictions), average='weighted')

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """Perform one validation epoch including static features.
    """
    model.eval()
    running_loss = 0.0
    all_predictions, all_targets = [], []

    with torch.no_grad():
        for inputs, x_static, targets in val_loader:
            inputs = inputs.to(device).float()
            x_static = x_static.to(device).float()
            targets = targets.to(device).float()

            with torch.amp.autocast(device_type=device.type, enabled=(device.type=='cuda')):
                logits = model(inputs, x_static)
                loss = criterion(logits, targets)

            running_loss += loss.item() * inputs.size(0)
            all_predictions.append((logits > 0.5).long().cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_f1 = f1_score(np.concatenate(all_targets), np.concatenate(all_predictions), average='weighted')

    return epoch_loss, epoch_f1

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """Log scalar metrics and histograms for model weights and gradients.
    """
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    for name, param in model.named_parameters():
        if param.requires_grad:
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None and param.grad.numel() > 0:
                writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name="", base_path="", scheduler=None):
    """Train the model with optional early stopping, scheduler, TensorBoard logging.
    """
    training_history = {'train_loss': [], 'val_loss': [], 'train_f1': [], 'val_f1': []}

    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    # Ensure model save directory exists
    os.makedirs(base_path+"models/", exist_ok=True)

    print(f"Training {epochs} epochs...")

    for epoch in range(1, epochs+1):
        # --- Training ---
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda
        )

        # --- Validation ---
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Scheduler step (if any)
        if scheduler is not None:
            metric_to_track = val_f1 if evaluation_metric=="val_f1" else val_loss
            scheduler.step(metric_to_track)

        # Store metrics
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # TensorBoard logging
        if writer is not None:
            log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model)

        # Verbose printing
        if verbose > 0 and (epoch % verbose == 0 or epoch==1):
            print(f"Epoch {epoch:3d}/{epochs} | "
                  f"Train: Loss={train_loss:.4f}, F1={train_f1:.4f} | "
                  f"Val: Loss={val_loss:.4f}, F1={val_f1:.4f}")

        # Early stopping
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode=='max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), base_path+"models/"+experiment_name+'_model.pt')
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best weights if early stopping used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load(base_path+"models/"+experiment_name+'_model.pt'))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric}={best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), base_path+"models/"+experiment_name+'_model.pt')

    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# ## Model Training

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %%
# Training configuration
LEARNING_RATE = 1e-3
EPOCHS = 500
PATIENCE = 100

# Architecture
HIDDEN_LAYERS = 2        # Hidden layers
HIDDEN_SIZE = 128        # Neurons per layer

# Regularisation
DROPOUT_RATE = 0.2         # Dropout probability
L1_LAMBDA = 0              # L1 penalty
L2_LAMBDA = 1e-4           # L2 penalty

# %%
# Create model and display architecture with parameter count
seq_input_dim = X_train_seq.shape[2]
static_input_dim = X_train_static.shape[1]

model = LSTMAttentionBinary(
    seq_input_dim=seq_input_dim,
    static_input_dim=static_input_dim,
    hidden_size=128,
    n_layers=2,
    dropout=0.3,
    bidirectional=True
).to(device)

experiment_name = "lstm_mlp_attention"
# Set up TensorBoard logging and save model architecture
# writer = SummaryWriter("./"+BASE_PATH+logs_dir+"/"+experiment_name)
# x = torch.randn(1, input_shape[0], input_shape[1]).to(device)
# writer.add_graph(rnn_model, x)

# %%
label_counts = y_train['label'].value_counts().values

counts = torch.tensor(label_counts, dtype=torch.float)
weights = counts.sum() / (counts * len(counts))
weights
# Out:
# tensor([0.7979, 1.3393])

# %%
# Set up loss function and optimizer
# criterion = nn.CrossEntropyLoss(weight=weights.to(device))
num_pos = (y_train_seq==1).sum()
num_neg = (y_train_seq==0).sum()
pos_weight = torch.tensor(num_neg/(num_pos+1e-8)).to(device)

# Loss
criterion = FocalLoss()  # more robust to class imbalance

# Ottimizzatore e scheduler
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10)

# Mixed precision
scaler = torch.amp.GradScaler(enabled=(device.type=='cuda'))


# Path for model savings
BASE_PATH = ""

# %%
# Train model and track training history
model, training_history = fit(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    device=device,
    l1_lambda=0,
    patience=PATIENCE,
    evaluation_metric="val_f1",
    restore_best_weights=True,
    verbose=1,
    experiment_name="lstm_attention_bin",
    base_path=BASE_PATH,
    scheduler=scheduler
)

# Update best model if current performance is superior
if training_history['val_f1'][-1] > best_performance:
    best_model = model
    best_performance = training_history['val_f1'][-1]
# Out:
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=0.1794, F1=0.3520 | Val: Loss=0.1771, F1=0.3333
# Epoch   2/500 | Train: Loss=0.1813, F1=0.2620 | Val: Loss=0.1777, F1=0.3333
# Epoch   3/500 | Train: Loss=0.1652, F1=0.4001 | Val: Loss=0.1762, F1=0.3333
# Epoch   4/500 | Train: Loss=0.1605, F1=0.3710 | Val: Loss=0.1756, F1=0.3333
# Epoch   5/500 | Train: Loss=0.1379, F1=0.3333 | Val: Loss=0.1829, F1=0.3333
# Epoch   6/500 | Train: Loss=0.1316, F1=0.4144 | Val: Loss=0.2106, F1=0.6411
# Epoch   7/500 | Train: Loss=0.0988, F1=0.7825 | Val: Loss=0.2755, F1=0.6229
# Epoch   8/500 | Train: Loss=0.1112, F1=0.7983 | Val: Loss=0.2961, F1=0.6528
# Epoch   9/500 | Train: Loss=0.1089, F1=0.8156 | Val: Loss=0.2618, F1=0.6528
# Epoch  10/500 | Train: Loss=0.0882, F1=0.8061 | Val: Loss=0.2416, F1=0.6528
# Epoch  11/500 | Train: Loss=0.0712, F1=0.8833 | Val: Loss=0.2398, F1=0.6229
# Epoch  12/500 | Train: Loss=0.0804, F1=0.8573 | Val: Loss=0.2514, F1=0.6229
# Epoch  13/500 | Train: Loss=0.0745, F1=0.8318 | Val: Loss=0.2764, F1=0.5928
# Epoch  14/500 | Train: Loss=0.0761, F1=0.8725 | Val: Loss=0.2558, F1=0.6229
# Epoch  15/500 | Train: Loss=0.0438, F1=0.9084 | Val: Loss=0.2683, F1=0.6229
# Epoch  16/500 | Train: Loss=0.0761, F1=0.8636 | Val: Loss=0.2797, F1=0.6229
# Epoch  17/500 | Train: Loss=0.0337, F1=0.9415 | Val: Loss=0.2682, F1=0.6970
# Epoch  18/500 | Train: Loss=0.0733, F1=0.9248 | Val: Loss=0.2453, F1=0.6970
# Epoch  19/500 | Train: Loss=0.0442, F1=0.9833 | Val: Loss=0.2662, F1=0.6606
# Epoch  20/500 | Train: Loss=0.0461, F1=0.9495 | Val: Loss=0.3019, F1=0.6606
# Epoch  21/500 | Train: Loss=0.0346, F1=0.9583 | Val: Loss=0.3363, F1=0.7664
# Epoch  22/500 | Train: Loss=0.0349, F1=0.9584 | Val: Loss=0.3607, F1=0.7664
# Epoch  23/500 | Train: Loss=0.0271, F1=0.9667 | Val: Loss=0.3598, F1=0.7664
# Epoch  24/500 | Train: Loss=0.0284, F1=0.9750 | Val: Loss=0.3502, F1=0.7664
# Epoch  25/500 | Train: Loss=0.0202, F1=0.9750 | Val: Loss=0.3823, F1=0.7664
# Epoch  26/500 | Train: Loss=0.0132, F1=0.9751 | Val: Loss=0.4396, F1=0.7664
# Epoch  27/500 | Train: Loss=0.0121, F1=0.9833 | Val: Loss=0.4997, F1=0.7664
# Epoch  28/500 | Train: Loss=0.0058, F1=0.9917 | Val: Loss=0.6066, F1=0.7664
# Epoch  29/500 | Train: Loss=0.0028, F1=1.0000 | Val: Loss=0.7394, F1=0.7321
# Epoch  30/500 | Train: Loss=0.0168, F1=0.9833 | Val: Loss=0.6659, F1=0.7964
# Epoch  31/500 | Train: Loss=0.0017, F1=1.0000 | Val: Loss=0.5368, F1=0.8316
# Epoch  32/500 | Train: Loss=0.0036, F1=1.0000 | Val: Loss=0.4361, F1=0.8990
# Epoch  33/500 | Train: Loss=0.0010, F1=1.0000 | Val: Loss=0.5240, F1=0.8331
# Epoch  34/500 | Train: Loss=0.0390, F1=0.9667 | Val: Loss=0.4386, F1=0.8990
# Epoch  35/500 | Train: Loss=0.0011, F1=1.0000 | Val: Loss=0.4448, F1=0.8990
# Epoch  36/500 | Train: Loss=0.0044, F1=1.0000 | Val: Loss=0.4241, F1=0.8990
# Epoch  37/500 | Train: Loss=0.0082, F1=0.9917 | Val: Loss=0.3864, F1=0.8990
# Epoch  38/500 | Train: Loss=0.0042, F1=0.9917 | Val: Loss=0.3566, F1=0.8990
# Epoch  39/500 | Train: Loss=0.0061, F1=0.9750 | Val: Loss=0.4350, F1=0.8661
# Epoch  40/500 | Train: Loss=0.0017, F1=0.9917 | Val: Loss=0.5715, F1=0.8000
# Epoch  41/500 | Train: Loss=0.0018, F1=0.9917 | Val: Loss=0.6978, F1=0.7664
# Epoch  42/500 | Train: Loss=0.0031, F1=0.9917 | Val: Loss=0.6408, F1=0.8000
# Epoch  43/500 | Train: Loss=0.0012, F1=1.0000 | Val: Loss=0.5355, F1=0.8661
# Epoch  44/500 | Train: Loss=0.0003, F1=1.0000 | Val: Loss=0.5195, F1=0.8661
# Epoch  45/500 | Train: Loss=0.0006, F1=1.0000 | Val: Loss=0.4891, F1=0.8661
# Epoch  46/500 | Train: Loss=0.0004, F1=1.0000 | Val: Loss=0.4807, F1=0.8661
# Epoch  47/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.4741, F1=0.8661
# Epoch  48/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.4665, F1=0.8990
# Epoch  49/500 | Train: Loss=0.0004, F1=1.0000 | Val: Loss=0.4626, F1=0.8990
# Epoch  50/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.4583, F1=0.8990
# Epoch  51/500 | Train: Loss=0.0003, F1=1.0000 | Val: Loss=0.4550, F1=0.8990
# Epoch  52/500 | Train: Loss=0.0003, F1=1.0000 | Val: Loss=0.4511, F1=0.8990
# Epoch  53/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.4464, F1=0.8990
# Epoch  54/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.4414, F1=0.8990
# Epoch  55/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.4386, F1=0.8990
# Epoch  56/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4359, F1=0.8990
# Epoch  57/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4331, F1=0.8990
# Epoch  58/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4301, F1=0.8990
# Epoch  59/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4274, F1=0.8990
# Epoch  60/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4247, F1=0.8990
# Epoch  61/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4217, F1=0.8990
# Epoch  62/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4185, F1=0.8990
# Epoch  63/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4154, F1=0.8990
# Epoch  64/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4110, F1=0.8990
# Epoch  65/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4055, F1=0.8990
# Epoch  66/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.4019, F1=0.8990
# Epoch  67/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3985, F1=0.8990
# Epoch  68/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3954, F1=0.8990
# Epoch  69/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.3934, F1=0.8990
# Epoch  70/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3920, F1=0.8990
# Epoch  71/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3906, F1=0.8990
# Epoch  72/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3893, F1=0.8990
# Epoch  73/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3882, F1=0.8990
# Epoch  74/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3871, F1=0.8990
# Epoch  75/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3861, F1=0.8990
# Epoch  76/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3854, F1=0.8990
# Epoch  77/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3852, F1=0.8990
# Epoch  78/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3849, F1=0.8990
# Epoch  79/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3848, F1=0.8990
# Epoch  80/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3846, F1=0.8990
# Epoch  81/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3844, F1=0.8990
# Epoch  82/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3842, F1=0.8990
# Epoch  83/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3840, F1=0.8990
# Epoch  84/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3837, F1=0.8990
# Epoch  85/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3836, F1=0.8990
# Epoch  86/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3833, F1=0.8990
# Epoch  87/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3829, F1=0.8990
# Epoch  88/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3829, F1=0.8990
# Epoch  89/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3828, F1=0.8990
# Epoch  90/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3827, F1=0.8990
# Epoch  91/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3826, F1=0.8990
# Epoch  92/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3825, F1=0.8990
# Epoch  93/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.3824, F1=0.8990
# Epoch  94/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3823, F1=0.8990
# Epoch  95/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.3822, F1=0.8990
# Epoch  96/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3822, F1=0.8990
# Epoch  97/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3821, F1=0.8990
# Epoch  98/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3820, F1=0.8990
# Epoch  99/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3819, F1=0.8990
# Epoch 100/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3819, F1=0.8990
# Epoch 101/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3818, F1=0.8990
# Epoch 102/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3817, F1=0.8990
# Epoch 103/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3817, F1=0.8990
# Epoch 104/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3816, F1=0.8990
# Epoch 105/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3816, F1=0.8990
# Epoch 106/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3815, F1=0.8990
# Epoch 107/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3815, F1=0.8990
# Epoch 108/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3814, F1=0.8990
# Epoch 109/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3814, F1=0.8990
# Epoch 110/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3814, F1=0.8990
# Epoch 111/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3813, F1=0.8990
# Epoch 112/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3813, F1=0.8990
# Epoch 113/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3813, F1=0.8990
# Epoch 114/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3813, F1=0.8990
# Epoch 115/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3813, F1=0.8990
# Epoch 116/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3813, F1=0.8990
# Epoch 117/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3812, F1=0.8990
# Epoch 118/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3812, F1=0.8990
# Epoch 119/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3812, F1=0.8990
# Epoch 120/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 121/500 | Train: Loss=0.0002, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 122/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 123/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 124/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 125/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 126/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 127/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3811, F1=0.8990
# Epoch 128/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3810, F1=0.8990
# Epoch 129/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3810, F1=0.8990
# Epoch 130/500 | Train: Loss=0.0000, F1=1.0000 | Val: Loss=0.3810, F1=0.8990
# Epoch 131/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3810, F1=0.8990
# Epoch 132/500 | Train: Loss=0.0001, F1=1.0000 | Val: Loss=0.3810, F1=0.8990
# Early stopping triggered after 132 epochs.
# Best model restored from epoch 32 with val_f1=0.8990

# %%
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# Collect predictions and ground truth labels
val_preds, val_targets = [], []

with torch.no_grad():  # Disable gradient computation
    for xb_dyn, xb_static, yb in val_loader:
        # Move data to device
        xb_dyn = xb_dyn.to(device).float()
        xb_static = xb_static.to(device).float()
        yb = yb.to(device)

        # Forward pass: get model predictions
        logits = model(xb_dyn, xb_static)
        preds = (logits > 0.5).long().cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.cpu().numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')

print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualize confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.9000
# Precision over the validation set: 0.9167
# Recall over the validation set: 0.9000
# F1 score over the validation set: 0.8990

# %% [markdown]
# ## StratifiedGroupKFold and Random Splits

# %%
# from sklearn.model_selection import StratifiedGroupKFold
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# import numpy as np
# import torch

# N_SPLITS = 5
# N_REPEATS = 3
# SEED = 42

# all_metrics = []
# subjects = df_subjects['sample_index'].values
# labels = df_subjects['label'].values

# for repeat in range(N_REPEATS):
#     sgkf = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED + repeat)

#     for fold, (train_idx, val_idx) in enumerate(sgkf.split(df_subjects, labels, groups=subjects)):
#         print(f"\n--- Repeat {repeat+1}, Fold {fold+1} ---")

#         train_users = df_subjects.iloc[train_idx]['sample_index'].values
#         val_users = df_subjects.iloc[val_idx]['sample_index'].values

#         df_train_fold = X_train[X_train['sample_index'].isin(train_users)]
#         df_val_fold = X_train[X_train['sample_index'].isin(val_users)]
#         y_train_fold = y_train[y_train['sample_index'].isin(train_users)]
#         y_val_fold = y_train[y_train['sample_index'].isin(val_users)]

#         X_train_seq, X_train_static, y_train_seq = build_sequences(df_train_fold, y_train_fold, augment=True)
#         X_val_seq, X_val_static, y_val_seq = build_sequences(df_val_fold, y_val_fold, augment=False)

#         train_ds = PirateDataset(X_train_seq, X_train_static, y_train_seq)
#         val_ds = PirateDataset(X_val_seq, X_val_static, y_val_seq)

#         train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
#         val_loader = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False)

#         model = CNN_GRU_Binary(
#           input_size_dynamic=X_train_seq.shape[-1],
#           input_size_static=X_train_static.shape[-1],
#           hidden_size=HIDDEN_SIZE,
#           num_layers=HIDDEN_LAYERS,
#           dropout_rate=DROPOUT_RATE,
#           bidirectional=False,
#           use_attention=True
#       ).to(device)

#         optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
#         scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#             optimizer, mode='max', factor=0.5, patience=15
#         )
#         scaler = torch.cuda.amp.GradScaler() if torch.cuda.is_available() else None

#         model, history = fit(
#             model, train_loader, val_loader,
#             epochs=EPOCHS,
#             criterion=criterion,
#             optimizer=optimizer,
#             scaler=scaler,
#             device=device,
#             l1_lambda=L1_LAMBDA,
#             l2_lambda=L2_LAMBDA,
#             patience=PATIENCE,
#             evaluation_metric='val_f1',
#             mode='max',
#             restore_best_weights=True,
#             verbose=10,
#             experiment_name=f"repeat{repeat+1}_fold{fold+1}",
#             base_path=BASE_PATH,
#             scheduler=scheduler  # pass scheduler to fit
#         )

#         # evaluate on validation fold
#         val_preds, val_targets = [], []
#         with torch.no_grad():
#             for xb_dyn, xb_static, yb in val_loader:
#                 xb_dyn, xb_static, yb = xb_dyn.to(device).float(), xb_static.to(device).float(), yb.to(device)
#                 logits = model(xb_dyn, xb_static)
#                 preds = logits.argmax(dim=1).cpu().numpy()
#                 val_preds.append(preds)
#                 val_targets.append(yb.cpu().numpy())

#         val_preds = np.concatenate(val_preds)
#         val_targets = np.concatenate(val_targets)

#         acc = accuracy_score(val_targets, val_preds)
#         f1 = f1_score(val_targets, val_preds, average='weighted')
#         prec = precision_score(val_targets, val_preds, average='weighted')
#         rec = recall_score(val_targets, val_preds, average='weighted')

#         all_metrics.append({'repeat': repeat+1, 'fold': fold+1,
#                             'accuracy': acc, 'f1': f1, 'precision': prec, 'recall': rec})

# # summary
# metrics_array = np.array([[m['accuracy'], m['f1'], m['precision'], m['recall']] for m in all_metrics])
# mean_metrics = metrics_array.mean(axis=0)
# std_metrics = metrics_array.std(axis=0)

# print("\n=== Cross-validated results with scheduler ===")
# print(f"Accuracy: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
# print(f"F1 score: {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
# print(f"Precision: {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
# print(f"Recall: {mean_metrics[3]:.4f} ± {std_metrics[3]:.4f}")

# %% [markdown]
# ## Optuna

# %%
import optuna
import torch
import torch.nn as nn
import numpy as np
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import f1_score

def objective(trial):
    # -----------------------
    # Hyperparameters to tune
    # -----------------------
    hidden_size = trial.suggest_int("hidden_size", 64, 256, step=32)
    num_layers = trial.suggest_int("num_layers", 1, 3)
    dropout = trial.suggest_float("dropout", 0.1, 0.5, step=0.05)
    bidirectional = trial.suggest_categorical("bidirectional", [True, False])
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-2)
    l1_lambda = trial.suggest_loguniform("l1_lambda", 1e-5, 1e-2)
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-5, 1e-2)

    window_size = trial.suggest_int("window_size", 100, 400, step=50)
    stride = trial.suggest_int("stride", 25, 200, step=25)
    batch_size = 64

    # -----------------------
    # StratifiedGroupKFold
    # -----------------------
    sgkf = StratifiedGroupKFold(n_splits=3, shuffle=True, random_state=42)
    df_subjects = X_train[['sample_index']].drop_duplicates().merge(y_train, on='sample_index')
    f1_scores = []

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for train_idx, val_idx in sgkf.split(df_subjects, df_subjects['label'], groups=df_subjects['sample_index']):
        train_users = df_subjects.iloc[train_idx]['sample_index'].values
        val_users = df_subjects.iloc[val_idx]['sample_index'].values

        df_tr = X_train[X_train['sample_index'].isin(train_users)]
        df_val = X_train[X_train['sample_index'].isin(val_users)]

        y_tr = y_train[y_train['sample_index'].isin(train_users)]
        y_val = y_train[y_train['sample_index'].isin(val_users)]

        X_tr_seq, X_tr_static, y_tr_seq = build_sequences(df_tr, y_tr, window=window_size, stride=stride, augment=True)
        X_val_seq, X_val_static, y_val_seq = build_sequences(df_val, y_val, window=window_size, stride=stride, augment=False)

        train_ds = PirateDataset(X_tr_seq, X_tr_static, y_tr_seq)
        val_ds = PirateDataset(X_val_seq, X_val_static, y_val_seq)

        train_loader = make_loader(train_ds, batch_size=batch_size)
        val_loader = make_loader(val_ds, batch_size=batch_size, shuffle=False)

        # -----------------------
        # Define LSTM+MLP model
        # -----------------------
        model = LSTMAttentionBinary(
            seq_input_dim=X_tr_seq.shape[2],
            static_input_dim=X_tr_static.shape[1],
            hidden_size=hidden_size,
            n_layers=num_layers,
            dropout=dropout,
            bidirectional=bidirectional
        ).to(device)

        # -----------------------
        # Loss + Optimizer
        # -----------------------
        num_pos = (y_tr_seq == 1).sum()
        num_neg = (y_tr_seq == 0).sum()
        pos_weight = torch.tensor(num_neg / (num_pos + 1e-8)).to(device)

        criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=l2_lambda)
        scaler = torch.amp.GradScaler(enabled=(device.type=='cuda'))
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10)

        # -----------------------
        # Train model
        # -----------------------
        model, history = fit(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            epochs=300,  # reduce for faster Optuna trials
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            device=device,
            l1_lambda=l1_lambda,
            l2_lambda=l2_lambda,
            patience=100,
            evaluation_metric="val_f1",
            mode='max',
            restore_best_weights=True,
            writer=None,
            verbose=0,
            experiment_name=f"optuna_trial"
        )

        # -----------------------
        # Validation F1
        # -----------------------
        val_preds, val_targets = [], []
        with torch.no_grad():
            for xb_dyn, xb_static, yb in val_loader:
                xb_dyn = xb_dyn.to(device).float()
                xb_static = xb_static.to(device).float()
                yb = yb.to(device).float()
                logits = model(xb_dyn, xb_static)
                preds = (torch.sigmoid(logits) > 0.5).cpu().numpy()
                val_preds.append(preds)
                val_targets.append(yb.cpu().numpy())

        val_preds = np.concatenate(val_preds)
        val_targets = np.concatenate(val_targets)
        f1_scores.append(f1_score(val_targets, val_preds))

    return np.mean(f1_scores)

# %%
study = optuna.create_study(
    direction="maximize",
    study_name="pirate_pain_optuna"
)

n_trials = 30
study.optimize(objective, n_trials=n_trials, n_jobs=1, show_progress_bar=True)

print("Best trial:")
trial = study.best_trial
print(f"F1 Score: {trial.value:.4f}")
print("Params:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-16 17:18:44,034] A new study created in memory with name: pirate_pain_optuna
#   0%|          | 0/30 [00:00<?, ?it/s]
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 17:20:29,115] Trial 0 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'bidirectional': False, 'learning_rate': 0.008435674114961168, 'l1_lambda': 0.008002501754669976, 'l2_lambda': 5.0835033302116975e-05, 'window_size': 100, 'stride': 50}. Best is trial 0 with value: 0.5434173669467787.
# Training 300 epochs...
# Early stopping triggered after 166 epochs.
# Best model restored from epoch 66 with val_f1=0.6685
# Training 300 epochs...
# Early stopping triggered after 205 epochs.
# Best model restored from epoch 105 with val_f1=0.7624
# Training 300 epochs...
# Early stopping triggered after 269 epochs.
# Best model restored from epoch 169 with val_f1=0.7624
# [I 2025-11-16 17:24:01,857] Trial 1 finished with value: 0.5552584670231729 and parameters: {'hidden_size': 128, 'num_layers': 1, 'dropout': 0.30000000000000004, 'bidirectional': True, 'learning_rate': 0.007533998303031761, 'l1_lambda': 4.3389631817326126e-05, 'l2_lambda': 2.0898148843341287e-05, 'window_size': 400, 'stride': 175}. Best is trial 1 with value: 0.5552584670231729.
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 17:25:41,846] Trial 2 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 224, 'num_layers': 3, 'dropout': 0.4, 'bidirectional': False, 'learning_rate': 0.0005035952220239692, 'l1_lambda': 0.0006295445922630307, 'l2_lambda': 0.00020639945904313774, 'window_size': 100, 'stride': 125}. Best is trial 1 with value: 0.5552584670231729.
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4500
# [I 2025-11-16 17:27:18,153] Trial 3 finished with value: 0.3669467787114846 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.25, 'bidirectional': False, 'learning_rate': 0.0038197843838443223, 'l1_lambda': 0.0005635363762228892, 'l2_lambda': 0.0005493405776367601, 'window_size': 100, 'stride': 125}. Best is trial 1 with value: 0.5552584670231729.
# Training 300 epochs...
# Early stopping triggered after 111 epochs.
# Best model restored from epoch 11 with val_f1=0.5774
# Training 300 epochs...
# Early stopping triggered after 116 epochs.
# Best model restored from epoch 16 with val_f1=0.6166
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 17:29:14,203] Trial 4 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 192, 'num_layers': 1, 'dropout': 0.45000000000000007, 'bidirectional': False, 'learning_rate': 0.0005825375386825602, 'l1_lambda': 0.00031239531261539427, 'l2_lambda': 1.4427060069252499e-05, 'window_size': 150, 'stride': 100}. Best is trial 1 with value: 0.5552584670231729.
# Training 300 epochs...
# Early stopping triggered after 272 epochs.
# Best model restored from epoch 172 with val_f1=0.7251
# Training 300 epochs...
# Best model restored from epoch 257 with val_f1=0.7906
# Training 300 epochs...
# Early stopping triggered after 176 epochs.
# Best model restored from epoch 76 with val_f1=0.7264
# [I 2025-11-16 17:33:40,618] Trial 5 finished with value: 0.6065833648870377 and parameters: {'hidden_size': 256, 'num_layers': 1, 'dropout': 0.2, 'bidirectional': True, 'learning_rate': 0.00010989196327198938, 'l1_lambda': 4.2685194037257245e-05, 'l2_lambda': 0.0007111426863835311, 'window_size': 100, 'stride': 100}. Best is trial 5 with value: 0.6065833648870377.
# Training 300 epochs...
# Best model restored from epoch 208 with val_f1=0.6668
# Training 300 epochs...
# Early stopping triggered after 165 epochs.
# Best model restored from epoch 65 with val_f1=0.7463
# Training 300 epochs...
# Early stopping triggered after 139 epochs.
# Best model restored from epoch 39 with val_f1=0.6070
# [I 2025-11-16 17:37:13,880] Trial 6 finished with value: 0.5430474076423022 and parameters: {'hidden_size': 160, 'num_layers': 1, 'dropout': 0.2, 'bidirectional': True, 'learning_rate': 0.00013171036039364892, 'l1_lambda': 0.0001422264705879979, 'l2_lambda': 2.3203978418545037e-05, 'window_size': 200, 'stride': 175}. Best is trial 5 with value: 0.6065833648870377.
# Training 300 epochs...
# Early stopping triggered after 104 epochs.
# Best model restored from epoch 4 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 106 epochs.
# Best model restored from epoch 6 with val_f1=0.4500
# [I 2025-11-16 17:38:57,395] Trial 7 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.4, 'bidirectional': True, 'learning_rate': 0.0024135373939820765, 'l1_lambda': 0.001667818455736964, 'l2_lambda': 0.0017879188808822438, 'window_size': 100, 'stride': 200}. Best is trial 5 with value: 0.6065833648870377.
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 221 epochs.
# Best model restored from epoch 121 with val_f1=0.7015
# [I 2025-11-16 17:41:18,551] Trial 8 finished with value: 0.19047619047619047 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.45000000000000007, 'bidirectional': True, 'learning_rate': 0.00013019313631413808, 'l1_lambda': 0.0007892685072342317, 'l2_lambda': 0.008948439020091093, 'window_size': 200, 'stride': 25}. Best is trial 5 with value: 0.6065833648870377.
# Training 300 epochs...
# Early stopping triggered after 207 epochs.
# Best model restored from epoch 107 with val_f1=0.7214
# Training 300 epochs...
# Early stopping triggered after 263 epochs.
# Best model restored from epoch 163 with val_f1=0.8071
# Training 300 epochs...
# Early stopping triggered after 134 epochs.
# Best model restored from epoch 34 with val_f1=0.7227
# [I 2025-11-16 17:45:41,149] Trial 9 finished with value: 0.5665849673202614 and parameters: {'hidden_size': 224, 'num_layers': 2, 'dropout': 0.35, 'bidirectional': True, 'learning_rate': 0.0011458532676838563, 'l1_lambda': 1.841096363032018e-05, 'l2_lambda': 1.7092685736764723e-05, 'window_size': 350, 'stride': 125}. Best is trial 5 with value: 0.6065833648870377.
# Training 300 epochs...
# Early stopping triggered after 291 epochs.
# Best model restored from epoch 191 with val_f1=0.8400
# Training 300 epochs...
# Early stopping triggered after 175 epochs.
# Best model restored from epoch 75 with val_f1=0.7463
# Training 300 epochs...
# Early stopping triggered after 136 epochs.
# Best model restored from epoch 36 with val_f1=0.7763
# [I 2025-11-16 17:49:41,162] Trial 10 finished with value: 0.6358306836248012 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.0002687751738774313, 'l1_lambda': 1.055309485866751e-05, 'l2_lambda': 0.0021143828998906587, 'window_size': 300, 'stride': 75}. Best is trial 10 with value: 0.6358306836248012.
# Training 300 epochs...
# Early stopping triggered after 229 epochs.
# Best model restored from epoch 129 with val_f1=0.7566
# Training 300 epochs...
# Early stopping triggered after 175 epochs.
# Best model restored from epoch 75 with val_f1=0.7056
# Training 300 epochs...
# Best model restored from epoch 267 with val_f1=0.8400
# [I 2025-11-16 17:54:16,950] Trial 11 finished with value: 0.6687830687830688 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.00025652806429587603, 'l1_lambda': 1.8259207818767372e-05, 'l2_lambda': 0.0022993616372701154, 'window_size': 300, 'stride': 75}. Best is trial 11 with value: 0.6687830687830688.
# Training 300 epochs...
# Best model restored from epoch 292 with val_f1=0.7436
# Training 300 epochs...
# Early stopping triggered after 226 epochs.
# Best model restored from epoch 126 with val_f1=0.8120
# Training 300 epochs...
# Best model restored from epoch 295 with val_f1=0.8207
# [I 2025-11-16 17:59:38,800] Trial 12 finished with value: 0.6743386243386243 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.00029808021640543724, 'l1_lambda': 1.0206926834676637e-05, 'l2_lambda': 0.0039691628650031004, 'window_size': 300, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Best model restored from epoch 296 with val_f1=0.7647
# Training 300 epochs...
# Early stopping triggered after 283 epochs.
# Best model restored from epoch 183 with val_f1=0.8071
# Training 300 epochs...
# Early stopping triggered after 142 epochs.
# Best model restored from epoch 42 with val_f1=0.7356
# [I 2025-11-16 18:06:16,530] Trial 13 finished with value: 0.6396487673083417 and parameters: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.00035331723122562477, 'l1_lambda': 4.467221821751995e-05, 'l2_lambda': 0.008415475552096329, 'window_size': 300, 'stride': 50}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 288 epochs.
# Best model restored from epoch 188 with val_f1=0.7340
# Training 300 epochs...
# Early stopping triggered after 183 epochs.
# Best model restored from epoch 83 with val_f1=0.7521
# Training 300 epochs...
# Early stopping triggered after 144 epochs.
# Best model restored from epoch 44 with val_f1=0.7980
# [I 2025-11-16 18:10:18,687] Trial 14 finished with value: 0.6121509209744503 and parameters: {'hidden_size': 224, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.0002307287436855977, 'l1_lambda': 1.0455663922771744e-05, 'l2_lambda': 0.0025772370455466286, 'window_size': 300, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 105 epochs.
# Best model restored from epoch 5 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 103 epochs.
# Best model restored from epoch 3 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 106 epochs.
# Best model restored from epoch 6 with val_f1=0.4500
# [I 2025-11-16 18:12:58,137] Trial 15 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.15000000000000002, 'bidirectional': True, 'learning_rate': 0.0009738120266455083, 'l1_lambda': 0.00010777943142714916, 'l2_lambda': 0.004234769012503477, 'window_size': 250, 'stride': 25}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 260 epochs.
# Best model restored from epoch 160 with val_f1=0.8000
# Training 300 epochs...
# Early stopping triggered after 292 epochs.
# Best model restored from epoch 192 with val_f1=0.7749
# Training 300 epochs...
# Early stopping triggered after 184 epochs.
# Best model restored from epoch 84 with val_f1=0.7790
# [I 2025-11-16 18:18:00,463] Trial 16 finished with value: 0.6576998050682261 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.15000000000000002, 'bidirectional': True, 'learning_rate': 0.0007338547510662687, 'l1_lambda': 2.6248381037168716e-05, 'l2_lambda': 0.00014789336866145305, 'window_size': 400, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 134 epochs.
# Best model restored from epoch 34 with val_f1=0.5868
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 18:20:31,859] Trial 17 finished with value: 0.3669467787114846 and parameters: {'hidden_size': 224, 'num_layers': 3, 'dropout': 0.25, 'bidirectional': True, 'learning_rate': 0.00020626688547637897, 'l1_lambda': 0.00012378553544536988, 'l2_lambda': 0.0009129850506137526, 'window_size': 350, 'stride': 50}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 18:22:35,057] Trial 18 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 160, 'num_layers': 3, 'dropout': 0.15000000000000002, 'bidirectional': False, 'learning_rate': 0.0013932522224272756, 'l1_lambda': 0.003690795079218876, 'l2_lambda': 0.004698722211433174, 'window_size': 250, 'stride': 150}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 148 epochs.
# Best model restored from epoch 48 with val_f1=0.6685
# Training 300 epochs...
# Early stopping triggered after 164 epochs.
# Best model restored from epoch 64 with val_f1=0.7390
# Training 300 epochs...
# Early stopping triggered after 172 epochs.
# Best model restored from epoch 72 with val_f1=0.7980
# [I 2025-11-16 18:25:13,954] Trial 19 finished with value: 0.5668691389599317 and parameters: {'hidden_size': 96, 'num_layers': 2, 'dropout': 0.5, 'bidirectional': True, 'learning_rate': 0.0003104984965899731, 'l1_lambda': 2.1111587098417088e-05, 'l2_lambda': 0.0014445748091710244, 'window_size': 350, 'stride': 100}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 146 epochs.
# Best model restored from epoch 46 with val_f1=0.6253
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 18:27:56,428] Trial 20 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.30000000000000004, 'bidirectional': True, 'learning_rate': 0.00042590958272325716, 'l1_lambda': 8.358783511821774e-05, 'l2_lambda': 0.0004111673552409325, 'window_size': 200, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Best model restored from epoch 245 with val_f1=0.7785
# Training 300 epochs...
# Early stopping triggered after 225 epochs.
# Best model restored from epoch 125 with val_f1=0.7390
# Training 300 epochs...
# Early stopping triggered after 147 epochs.
# Best model restored from epoch 47 with val_f1=0.7576
# [I 2025-11-16 18:32:36,600] Trial 21 finished with value: 0.6357631771376512 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.15000000000000002, 'bidirectional': True, 'learning_rate': 0.0006921155138405699, 'l1_lambda': 2.2004066596895175e-05, 'l2_lambda': 0.0001707227695230828, 'window_size': 400, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 219 epochs.
# Best model restored from epoch 119 with val_f1=0.7107
# Training 300 epochs...
# Early stopping triggered after 185 epochs.
# Best model restored from epoch 85 with val_f1=0.7247
# Training 300 epochs...
# Early stopping triggered after 172 epochs.
# Best model restored from epoch 72 with val_f1=0.7727
# [I 2025-11-16 18:36:21,361] Trial 22 finished with value: 0.608207510646535 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.0001928402308317226, 'l1_lambda': 2.5796275711804578e-05, 'l2_lambda': 8.337920598297073e-05, 'window_size': 250, 'stride': 50}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 270 epochs.
# Best model restored from epoch 170 with val_f1=0.7971
# Training 300 epochs...
# Early stopping triggered after 196 epochs.
# Best model restored from epoch 96 with val_f1=0.8120
# Training 300 epochs...
# Early stopping triggered after 128 epochs.
# Best model restored from epoch 28 with val_f1=0.7980
# [I 2025-11-16 18:40:29,232] Trial 23 finished with value: 0.6437908496732027 and parameters: {'hidden_size': 224, 'num_layers': 2, 'dropout': 0.15000000000000002, 'bidirectional': True, 'learning_rate': 0.0008293106666237576, 'l1_lambda': 1.0656815381416443e-05, 'l2_lambda': 9.176463218387222e-05, 'window_size': 400, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 108 epochs.
# Best model restored from epoch 8 with val_f1=0.5708
# Training 300 epochs...
# Early stopping triggered after 102 epochs.
# Best model restored from epoch 2 with val_f1=0.4500
# [I 2025-11-16 18:42:35,619] Trial 24 finished with value: 0.3669467787114846 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.0016631493522813214, 'l1_lambda': 6.73723689165952e-05, 'l2_lambda': 0.004300423601523444, 'window_size': 350, 'stride': 100}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 111 epochs.
# Best model restored from epoch 11 with val_f1=0.4995
# Training 300 epochs...
# Early stopping triggered after 101 epochs.
# Best model restored from epoch 1 with val_f1=0.4500
# [I 2025-11-16 18:44:41,509] Trial 25 finished with value: 0.5434173669467787 and parameters: {'hidden_size': 224, 'num_layers': 2, 'dropout': 0.15000000000000002, 'bidirectional': True, 'learning_rate': 0.0004642350757692565, 'l1_lambda': 0.00023984092995072293, 'l2_lambda': 0.001017463467442562, 'window_size': 300, 'stride': 25}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 140 epochs.
# Best model restored from epoch 40 with val_f1=0.5840
# Training 300 epochs...
# Best model restored from epoch 284 with val_f1=0.6863
# Training 300 epochs...
# Early stopping triggered after 134 epochs.
# Best model restored from epoch 34 with val_f1=0.6084
# [I 2025-11-16 18:48:30,169] Trial 26 finished with value: 0.5639164756811815 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout': 0.25, 'bidirectional': False, 'learning_rate': 0.0001637268781900946, 'l1_lambda': 1.7151013820094092e-05, 'l2_lambda': 0.0002557972992699022, 'window_size': 350, 'stride': 50}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 134 epochs.
# Best model restored from epoch 34 with val_f1=0.6721
# Training 300 epochs...
# Early stopping triggered after 195 epochs.
# Best model restored from epoch 95 with val_f1=0.7390
# Training 300 epochs...
# Early stopping triggered after 190 epochs.
# Best model restored from epoch 90 with val_f1=0.7763
# [I 2025-11-16 18:51:57,497] Trial 27 finished with value: 0.5707472178060414 and parameters: {'hidden_size': 160, 'num_layers': 1, 'dropout': 0.2, 'bidirectional': True, 'learning_rate': 0.00030545902128518044, 'l1_lambda': 3.602639265685425e-05, 'l2_lambda': 0.00013930732391279692, 'window_size': 300, 'stride': 75}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 207 epochs.
# Best model restored from epoch 107 with val_f1=0.7569
# Training 300 epochs...
# Early stopping triggered after 148 epochs.
# Best model restored from epoch 48 with val_f1=0.5673
# Training 300 epochs...
# Early stopping triggered after 103 epochs.
# Best model restored from epoch 3 with val_f1=0.4500
# [I 2025-11-16 18:55:09,720] Trial 28 finished with value: 0.5389897894641728 and parameters: {'hidden_size': 224, 'num_layers': 2, 'dropout': 0.1, 'bidirectional': True, 'learning_rate': 0.0018372993360109497, 'l1_lambda': 6.157715852923393e-05, 'l2_lambda': 3.832771876979797e-05, 'window_size': 400, 'stride': 100}. Best is trial 12 with value: 0.6743386243386243.
# Training 300 epochs...
# Early stopping triggered after 139 epochs.
# Best model restored from epoch 39 with val_f1=0.6405
# Training 300 epochs...
# Best model restored from epoch 263 with val_f1=0.7934
# Training 300 epochs...
# Early stopping triggered after 106 epochs.
# Best model restored from epoch 6 with val_f1=0.4938
# [I 2025-11-16 18:58:12,537] Trial 29 finished with value: 0.5831629949277007 and parameters: {'hidden_size': 256, 'num_layers': 1, 'dropout': 0.2, 'bidirectional': False, 'learning_rate': 0.0006693916035683951, 'l1_lambda': 0.00019440465034285012, 'l2_lambda': 0.0003603313024772805, 'window_size': 250, 'stride': 50}. Best is trial 12 with value: 0.6743386243386243.
# Best trial:
#   F1 Score: 0.6743
#   Params:
#     hidden_size: 256
#     num_layers: 2
#     dropout: 0.1
#     bidirectional: True
#     learning_rate: 0.00029808021640543724
#     l1_lambda: 1.0206926834676637e-05
#     l2_lambda: 0.0039691628650031004
#     window_size: 300
#     stride: 75

# %%
# Example: best_params returned by Optuna
# best_params = study.best_trial.params

best_params = {
    'hidden_size': 224,
    'num_layers': 3,
    'dropout_rate': 0.5,
    'bidirectional': False,
    'use_attention': True,
    'learning_rate': 0.0006681049777712333,
    'l1_lambda': 2.2269656369662347e-05,
    'l2_lambda': 0.001482264917853986,
    'window_size': 100,
    'stride': 25
}

# Assign parameters from dictionary
HIDDEN_SIZE = best_params["hidden_size"]
HIDDEN_LAYERS = best_params["num_layers"]
DROPOUT_RATE = best_params["dropout_rate"]
BIDIRECTIONAL = best_params["bidirectional"]
USE_ATTENTION = best_params["use_attention"]
LEARNING_RATE = best_params["learning_rate"]
L1_LAMBDA = best_params["l1_lambda"]
L2_LAMBDA = best_params["l2_lambda"]
WINDOW_SIZE = best_params["window_size"]
STRIDE = best_params["stride"]

# DataLoader settings
BATCH_SIZE = 64
N_SPLITS = 5
N_REPEATS = 3
SEED = 42

all_metrics = []
subjects = df_subjects['sample_index'].values
labels = df_subjects['label'].values

for repeat in range(N_REPEATS):
    sgkf = StratifiedGroupKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED + repeat)

    for fold, (train_idx, val_idx) in enumerate(sgkf.split(df_subjects, labels, groups=subjects)):
        print(f"\n--- Repeat {repeat+1}, Fold {fold+1} ---")

        train_users = df_subjects.iloc[train_idx]['sample_index'].values
        val_users = df_subjects.iloc[val_idx]['sample_index'].values

        df_train_fold = X_train[X_train['sample_index'].isin(train_users)]
        df_val_fold = X_train[X_train['sample_index'].isin(val_users)]
        y_train_fold = y_train[y_train['sample_index'].isin(train_users)]
        y_val_fold = y_train[y_train['sample_index'].isin(val_users)]

        # Build sequences using optimal window and stride
        X_train_seq, X_train_static, y_train_seq = build_sequences(
            df_train_fold, y_train_fold, window=WINDOW_SIZE, stride=STRIDE, augment=True
        )
        X_val_seq, X_val_static, y_val_seq = build_sequences(
            df_val_fold, y_val_fold, window=WINDOW_SIZE, stride=STRIDE, augment=False
        )

        train_ds = PirateDataset(X_train_seq, X_train_static, y_train_seq)
        val_ds = PirateDataset(X_val_seq, X_val_static, y_val_seq)

        train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False)

        # Initialize model with best parameters
        model = CNN_GRU_Binary(
            input_size_dynamic=X_train_seq.shape[-1],
            input_size_static=X_train_static.shape[-1],
            hidden_size=HIDDEN_SIZE,
            num_layers=HIDDEN_LAYERS,
            dropout_rate=DROPOUT_RATE,
            bidirectional=BIDIRECTIONAL,
            use_attention=USE_ATTENTION
        ).to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='max', factor=0.5, patience=15
        )
        scaler = torch.cuda.amp.GradScaler() if torch.cuda.is_available() else None

        model, history = fit(
            model, train_loader, val_loader,
            epochs=EPOCHS,
            criterion=criterion,
            optimizer=optimizer,
            scaler=scaler,
            device=device,
            l1_lambda=L1_LAMBDA,
            l2_lambda=L2_LAMBDA,
            patience=PATIENCE,
            evaluation_metric='val_f1',
            mode='max',
            restore_best_weights=True,
            verbose=10,
            experiment_name=f"repeat{repeat+1}_fold{fold+1}",
            base_path=BASE_PATH,
            scheduler=scheduler
        )

        # Evaluate on validation fold
        val_preds, val_targets = [], []
        with torch.no_grad():
            for xb_dyn, xb_static, yb in val_loader:
                xb_dyn, xb_static, yb = xb_dyn.to(device).float(), xb_static.to(device).float(), yb.to(device)
                logits = model(xb_dyn, xb_static)
                preds = logits.argmax(dim=1).cpu().numpy()
                val_preds.append(preds)
                val_targets.append(yb.cpu().numpy())

        val_preds = np.concatenate(val_preds)
        val_targets = np.concatenate(val_targets)

        acc = accuracy_score(val_targets, val_preds)
        f1 = f1_score(val_targets, val_preds, average='weighted')
        prec = precision_score(val_targets, val_preds, average='weighted')
        rec = recall_score(val_targets, val_preds, average='weighted')

        all_metrics.append({
            'repeat': repeat+1, 'fold': fold+1,
            'accuracy': acc, 'f1': f1, 'precision': prec, 'recall': rec
        })

# Summary statistics
metrics_array = np.array([[m['accuracy'], m['f1'], m['precision'], m['recall']] for m in all_metrics])
mean_metrics = metrics_array.mean(axis=0)
std_metrics = metrics_array.std(axis=0)

print("\n=== Cross-validated results with Optuna best_params ===")
print(f"Accuracy: {mean_metrics[0]:.4f} ± {std_metrics[0]:.4f}")
print(f"F1 score: {mean_metrics[1]:.4f} ± {std_metrics[1]:.4f}")
print(f"Precision: {mean_metrics[2]:.4f} ± {std_metrics[2]:.4f}")
print(f"Recall: {mean_metrics[3]:.4f} ± {std_metrics[3]:.4f}")
# Out:
# --- Repeat 1, Fold 1 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3141, F1=0.5954 | Val: Loss=0.6928, F1=0.4391
# Epoch  10/500 | Train: Loss=0.4302, F1=0.9850 | Val: Loss=0.5793, F1=0.8643
# Epoch  20/500 | Train: Loss=0.3572, F1=0.9817 | Val: Loss=0.6055, F1=0.8200
# Epoch  30/500 | Train: Loss=0.2913, F1=1.0000 | Val: Loss=0.7069, F1=0.8035
# Epoch  40/500 | Train: Loss=0.2877, F1=0.9933 | Val: Loss=0.6892, F1=0.8265
# Epoch  50/500 | Train: Loss=0.2659, F1=0.9967 | Val: Loss=0.6895, F1=0.8213
# Epoch  60/500 | Train: Loss=0.2564, F1=1.0000 | Val: Loss=0.5487, F1=0.8643
# Epoch  70/500 | Train: Loss=0.2541, F1=0.9983 | Val: Loss=0.5618, F1=0.8643
# Epoch  80/500 | Train: Loss=0.2469, F1=1.0000 | Val: Loss=0.5132, F1=0.8713
# Epoch  90/500 | Train: Loss=0.2444, F1=1.0000 | Val: Loss=0.5460, F1=0.8643
# Epoch 100/500 | Train: Loss=0.2431, F1=1.0000 | Val: Loss=0.5527, F1=0.8643
# Early stopping triggered after 107 epochs.
# Best model restored from epoch 7 with val_f1=0.9266
#
# --- Repeat 1, Fold 2 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3089, F1=0.6250 | Val: Loss=0.5983, F1=0.6699
# Epoch  10/500 | Train: Loss=0.4531, F1=0.9783 | Val: Loss=0.5274, F1=0.8795
# Epoch  20/500 | Train: Loss=0.3752, F1=0.9800 | Val: Loss=2.0876, F1=0.3662
# Epoch  30/500 | Train: Loss=0.3166, F1=0.9917 | Val: Loss=0.8021, F1=0.7537
# Epoch  40/500 | Train: Loss=0.2768, F1=0.9967 | Val: Loss=0.5103, F1=0.8541
# Epoch  50/500 | Train: Loss=0.2439, F1=1.0000 | Val: Loss=0.6369, F1=0.8631
# Epoch  60/500 | Train: Loss=0.2343, F1=1.0000 | Val: Loss=0.7251, F1=0.8210
# Epoch  70/500 | Train: Loss=0.2292, F1=1.0000 | Val: Loss=0.5817, F1=0.8751
# Epoch  80/500 | Train: Loss=0.2261, F1=1.0000 | Val: Loss=0.5439, F1=0.8872
# Epoch  90/500 | Train: Loss=0.2234, F1=0.9983 | Val: Loss=0.5424, F1=0.8872
# Epoch 100/500 | Train: Loss=0.2204, F1=1.0000 | Val: Loss=0.5576, F1=0.8872
# Epoch 110/500 | Train: Loss=0.2190, F1=1.0000 | Val: Loss=0.5654, F1=0.8872
# Epoch 120/500 | Train: Loss=0.2193, F1=1.0000 | Val: Loss=0.5859, F1=0.8751
# Early stopping triggered after 125 epochs.
# Best model restored from epoch 25 with val_f1=0.9175
#
# --- Repeat 1, Fold 3 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3294, F1=0.5769 | Val: Loss=0.7003, F1=0.4913
# Epoch  10/500 | Train: Loss=0.4675, F1=0.9633 | Val: Loss=0.5993, F1=0.8433
# Epoch  20/500 | Train: Loss=0.3408, F1=0.9900 | Val: Loss=0.4433, F1=0.8809
# Epoch  30/500 | Train: Loss=0.2995, F1=0.9917 | Val: Loss=0.4834, F1=0.8747
# Epoch  40/500 | Train: Loss=0.2583, F1=1.0000 | Val: Loss=0.4703, F1=0.8853
# Epoch  50/500 | Train: Loss=0.2452, F1=0.9983 | Val: Loss=0.3866, F1=0.9104
# Epoch  60/500 | Train: Loss=0.2355, F1=0.9967 | Val: Loss=0.3719, F1=0.8941
# Epoch  70/500 | Train: Loss=0.2222, F1=1.0000 | Val: Loss=0.3083, F1=0.9354
# Epoch  80/500 | Train: Loss=0.2171, F1=1.0000 | Val: Loss=0.3166, F1=0.9354
# Epoch  90/500 | Train: Loss=0.2166, F1=1.0000 | Val: Loss=0.3184, F1=0.9354
# Epoch 100/500 | Train: Loss=0.2166, F1=0.9983 | Val: Loss=0.3067, F1=0.9288
# Epoch 110/500 | Train: Loss=0.2107, F1=1.0000 | Val: Loss=0.3289, F1=0.9354
# Epoch 120/500 | Train: Loss=0.2114, F1=1.0000 | Val: Loss=0.3483, F1=0.9167
# Epoch 130/500 | Train: Loss=0.2104, F1=1.0000 | Val: Loss=0.3510, F1=0.9292
# Epoch 140/500 | Train: Loss=0.2096, F1=1.0000 | Val: Loss=0.3321, F1=0.9354
# Early stopping triggered after 148 epochs.
# Best model restored from epoch 48 with val_f1=0.9354
#
# --- Repeat 1, Fold 4 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3348, F1=0.5756 | Val: Loss=0.6900, F1=0.3333
# Epoch  10/500 | Train: Loss=0.4693, F1=0.9617 | Val: Loss=0.7875, F1=0.6100
# Epoch  20/500 | Train: Loss=0.3476, F1=0.9883 | Val: Loss=1.2838, F1=0.5347
# Epoch  30/500 | Train: Loss=0.2964, F1=0.9933 | Val: Loss=1.6002, F1=0.4784
# Epoch  40/500 | Train: Loss=0.2573, F1=1.0000 | Val: Loss=0.6437, F1=0.7841
# Epoch  50/500 | Train: Loss=0.2437, F1=1.0000 | Val: Loss=0.6229, F1=0.7917
# Epoch  60/500 | Train: Loss=0.2355, F1=1.0000 | Val: Loss=0.7258, F1=0.7532
# Epoch  70/500 | Train: Loss=0.2303, F1=1.0000 | Val: Loss=0.8389, F1=0.6962
# Epoch  80/500 | Train: Loss=0.2272, F1=1.0000 | Val: Loss=0.6999, F1=0.7611
# Epoch  90/500 | Train: Loss=0.2252, F1=1.0000 | Val: Loss=0.9676, F1=0.6877
# Epoch 100/500 | Train: Loss=0.2233, F1=1.0000 | Val: Loss=0.8019, F1=0.7293
# Epoch 110/500 | Train: Loss=0.2228, F1=1.0000 | Val: Loss=0.7645, F1=0.7374
# Early stopping triggered after 119 epochs.
# Best model restored from epoch 19 with val_f1=0.9333
#
# --- Repeat 1, Fold 5 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3370, F1=0.5565 | Val: Loss=0.6963, F1=0.3041
# Epoch  10/500 | Train: Loss=0.4456, F1=0.9767 | Val: Loss=0.5586, F1=0.8577
# Epoch  20/500 | Train: Loss=0.3354, F1=0.9933 | Val: Loss=0.5372, F1=0.8539
# Epoch  30/500 | Train: Loss=0.2839, F1=0.9967 | Val: Loss=0.7875, F1=0.7523
# Epoch  40/500 | Train: Loss=0.2672, F1=0.9867 | Val: Loss=1.0334, F1=0.6749
# Epoch  50/500 | Train: Loss=0.2521, F1=0.9900 | Val: Loss=0.5106, F1=0.8860
# Epoch  60/500 | Train: Loss=0.2156, F1=1.0000 | Val: Loss=0.3868, F1=0.9251
# Epoch  70/500 | Train: Loss=0.2068, F1=1.0000 | Val: Loss=0.3864, F1=0.9185
# Epoch  80/500 | Train: Loss=0.2097, F1=0.9983 | Val: Loss=0.3488, F1=0.9251
# Epoch  90/500 | Train: Loss=0.2021, F1=1.0000 | Val: Loss=0.3842, F1=0.9180
# Epoch 100/500 | Train: Loss=0.1999, F1=1.0000 | Val: Loss=0.3478, F1=0.9251
# Epoch 110/500 | Train: Loss=0.1995, F1=1.0000 | Val: Loss=0.3551, F1=0.9185
# Epoch 120/500 | Train: Loss=0.1989, F1=1.0000 | Val: Loss=0.3121, F1=0.9324
# Epoch 130/500 | Train: Loss=0.1980, F1=1.0000 | Val: Loss=0.3325, F1=0.9251
# Epoch 140/500 | Train: Loss=0.1976, F1=1.0000 | Val: Loss=0.3229, F1=0.9251
# Epoch 150/500 | Train: Loss=0.1975, F1=1.0000 | Val: Loss=0.3325, F1=0.9255
# Epoch 160/500 | Train: Loss=0.1969, F1=1.0000 | Val: Loss=0.3065, F1=0.9390
# Epoch 170/500 | Train: Loss=0.1972, F1=1.0000 | Val: Loss=0.3312, F1=0.9255
# Epoch 180/500 | Train: Loss=0.1968, F1=1.0000 | Val: Loss=0.3204, F1=0.9324
# Epoch 190/500 | Train: Loss=0.1969, F1=1.0000 | Val: Loss=0.3318, F1=0.9255
# Epoch 200/500 | Train: Loss=0.1978, F1=1.0000 | Val: Loss=0.3363, F1=0.9255
# Epoch 210/500 | Train: Loss=0.1964, F1=1.0000 | Val: Loss=0.3135, F1=0.9328
# Epoch 220/500 | Train: Loss=0.1965, F1=1.0000 | Val: Loss=0.3511, F1=0.9185
# Epoch 230/500 | Train: Loss=0.1976, F1=1.0000 | Val: Loss=0.3298, F1=0.9255
# Epoch 240/500 | Train: Loss=0.1967, F1=1.0000 | Val: Loss=0.3383, F1=0.9251
# Epoch 250/500 | Train: Loss=0.1971, F1=1.0000 | Val: Loss=0.3167, F1=0.9328
# Early stopping triggered after 259 epochs.
# Best model restored from epoch 159 with val_f1=0.9530
#
# --- Repeat 2, Fold 1 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3251, F1=0.5663 | Val: Loss=0.6920, F1=0.4284
# Epoch  10/500 | Train: Loss=0.4747, F1=0.9700 | Val: Loss=1.0601, F1=0.6511
# Epoch  20/500 | Train: Loss=0.3440, F1=0.9900 | Val: Loss=0.4798, F1=0.8665
# Epoch  30/500 | Train: Loss=0.2855, F1=0.9950 | Val: Loss=0.7259, F1=0.7860
# Epoch  40/500 | Train: Loss=0.2570, F1=0.9983 | Val: Loss=0.4777, F1=0.8716
# Epoch  50/500 | Train: Loss=0.2672, F1=0.9867 | Val: Loss=0.6354, F1=0.7922
# Epoch  60/500 | Train: Loss=0.2288, F1=1.0000 | Val: Loss=0.4414, F1=0.8661
# Epoch  70/500 | Train: Loss=0.2216, F1=1.0000 | Val: Loss=0.4312, F1=0.9000
# Epoch  80/500 | Train: Loss=0.2164, F1=1.0000 | Val: Loss=0.4554, F1=0.8786
# Epoch  90/500 | Train: Loss=0.2124, F1=1.0000 | Val: Loss=0.4330, F1=0.8786
# Epoch 100/500 | Train: Loss=0.2106, F1=1.0000 | Val: Loss=0.4542, F1=0.8792
# Epoch 110/500 | Train: Loss=0.2096, F1=1.0000 | Val: Loss=0.3866, F1=0.9199
# Epoch 120/500 | Train: Loss=0.2103, F1=1.0000 | Val: Loss=0.4305, F1=0.8792
# Epoch 130/500 | Train: Loss=0.2076, F1=1.0000 | Val: Loss=0.4195, F1=0.8792
# Epoch 140/500 | Train: Loss=0.2075, F1=1.0000 | Val: Loss=0.4526, F1=0.8724
# Early stopping triggered after 148 epochs.
# Best model restored from epoch 48 with val_f1=0.9265
#
# --- Repeat 2, Fold 2 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3234, F1=0.5957 | Val: Loss=0.6442, F1=0.4500
# Epoch  10/500 | Train: Loss=0.4734, F1=0.9583 | Val: Loss=0.6841, F1=0.7286
# Epoch  20/500 | Train: Loss=0.3598, F1=0.9833 | Val: Loss=0.4801, F1=0.8482
# Epoch  30/500 | Train: Loss=0.3167, F1=0.9900 | Val: Loss=1.2449, F1=0.5756
# Epoch  40/500 | Train: Loss=0.2621, F1=0.9950 | Val: Loss=0.3074, F1=0.9331
# Epoch  50/500 | Train: Loss=0.2375, F1=1.0000 | Val: Loss=0.2897, F1=0.9321
# Epoch  60/500 | Train: Loss=0.2311, F1=0.9967 | Val: Loss=0.3323, F1=0.9268
# Epoch  70/500 | Train: Loss=0.2162, F1=1.0000 | Val: Loss=0.2492, F1=0.9664
# Epoch  80/500 | Train: Loss=0.2159, F1=0.9983 | Val: Loss=0.2968, F1=0.9321
# Epoch  90/500 | Train: Loss=0.2093, F1=0.9983 | Val: Loss=0.2459, F1=0.9664
# Epoch 100/500 | Train: Loss=0.2070, F1=1.0000 | Val: Loss=0.2407, F1=0.9664
# Epoch 110/500 | Train: Loss=0.2039, F1=1.0000 | Val: Loss=0.2465, F1=0.9597
# Epoch 120/500 | Train: Loss=0.2057, F1=0.9983 | Val: Loss=0.2529, F1=0.9531
# Epoch 130/500 | Train: Loss=0.2024, F1=1.0000 | Val: Loss=0.2406, F1=0.9664
# Epoch 140/500 | Train: Loss=0.2029, F1=1.0000 | Val: Loss=0.2546, F1=0.9531
# Epoch 150/500 | Train: Loss=0.2019, F1=1.0000 | Val: Loss=0.2424, F1=0.9597
# Early stopping triggered after 156 epochs.
# Best model restored from epoch 56 with val_f1=0.9664
#
# --- Repeat 2, Fold 3 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3264, F1=0.5726 | Val: Loss=0.6482, F1=0.5749
# Epoch  10/500 | Train: Loss=0.5173, F1=0.9483 | Val: Loss=0.6976, F1=0.8248
# Epoch  20/500 | Train: Loss=0.3903, F1=0.9767 | Val: Loss=0.8516, F1=0.6777
# Epoch  30/500 | Train: Loss=0.3300, F1=0.9800 | Val: Loss=0.6563, F1=0.8169
# Epoch  40/500 | Train: Loss=0.2737, F1=0.9917 | Val: Loss=0.6797, F1=0.8175
# Epoch  50/500 | Train: Loss=0.2412, F1=1.0000 | Val: Loss=0.5711, F1=0.8435
# Epoch  60/500 | Train: Loss=0.2338, F1=0.9967 | Val: Loss=0.4855, F1=0.8625
# Epoch  70/500 | Train: Loss=0.2234, F1=1.0000 | Val: Loss=0.4938, F1=0.8667
# Epoch  80/500 | Train: Loss=0.2204, F1=1.0000 | Val: Loss=0.4679, F1=0.8892
# Epoch  90/500 | Train: Loss=0.2190, F1=0.9983 | Val: Loss=0.4510, F1=0.8883
# Epoch 100/500 | Train: Loss=0.2111, F1=1.0000 | Val: Loss=0.4493, F1=0.8883
# Epoch 110/500 | Train: Loss=0.2088, F1=1.0000 | Val: Loss=0.4460, F1=0.8951
# Epoch 120/500 | Train: Loss=0.2094, F1=0.9983 | Val: Loss=0.4474, F1=0.9018
# Epoch 130/500 | Train: Loss=0.2060, F1=1.0000 | Val: Loss=0.4507, F1=0.8879
# Epoch 140/500 | Train: Loss=0.2031, F1=1.0000 | Val: Loss=0.4485, F1=0.8883
# Epoch 150/500 | Train: Loss=0.2027, F1=1.0000 | Val: Loss=0.4560, F1=0.8947
# Epoch 160/500 | Train: Loss=0.2015, F1=1.0000 | Val: Loss=0.4568, F1=0.9011
# Epoch 170/500 | Train: Loss=0.2018, F1=1.0000 | Val: Loss=0.4381, F1=0.9015
# Epoch 180/500 | Train: Loss=0.2018, F1=1.0000 | Val: Loss=0.4419, F1=0.9015
# Epoch 190/500 | Train: Loss=0.2011, F1=1.0000 | Val: Loss=0.4420, F1=0.8947
# Epoch 200/500 | Train: Loss=0.2024, F1=0.9983 | Val: Loss=0.4546, F1=0.8879
# Epoch 210/500 | Train: Loss=0.2008, F1=1.0000 | Val: Loss=0.4412, F1=0.9015
# Epoch 220/500 | Train: Loss=0.2007, F1=1.0000 | Val: Loss=0.4422, F1=0.9015
# Early stopping triggered after 220 epochs.
# Best model restored from epoch 120 with val_f1=0.9018
#
# --- Repeat 2, Fold 4 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3205, F1=0.5612 | Val: Loss=0.6159, F1=0.5333
# Epoch  10/500 | Train: Loss=0.4224, F1=0.9850 | Val: Loss=0.4026, F1=0.8817
# Epoch  20/500 | Train: Loss=0.3334, F1=0.9917 | Val: Loss=0.6578, F1=0.7924
# Epoch  30/500 | Train: Loss=0.2875, F1=0.9933 | Val: Loss=0.4318, F1=0.8679
# Epoch  40/500 | Train: Loss=0.2519, F1=1.0000 | Val: Loss=0.4359, F1=0.8640
# Epoch  50/500 | Train: Loss=0.2339, F1=1.0000 | Val: Loss=0.4491, F1=0.8640
# Epoch  60/500 | Train: Loss=0.2253, F1=1.0000 | Val: Loss=0.3217, F1=0.9383
# Epoch  70/500 | Train: Loss=0.2234, F1=0.9967 | Val: Loss=0.3321, F1=0.9251
# Epoch  80/500 | Train: Loss=0.2166, F1=1.0000 | Val: Loss=0.3248, F1=0.9383
# Epoch  90/500 | Train: Loss=0.2149, F1=1.0000 | Val: Loss=0.3288, F1=0.9383
# Epoch 100/500 | Train: Loss=0.2131, F1=1.0000 | Val: Loss=0.3184, F1=0.9383
# Epoch 110/500 | Train: Loss=0.2153, F1=0.9967 | Val: Loss=0.3235, F1=0.9383
# Epoch 120/500 | Train: Loss=0.2127, F1=1.0000 | Val: Loss=0.3277, F1=0.9383
# Early stopping triggered after 121 epochs.
# Best model restored from epoch 21 with val_f1=0.9383
#
# --- Repeat 2, Fold 5 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3252, F1=0.6053 | Val: Loss=0.6141, F1=0.5269
# Epoch  10/500 | Train: Loss=0.4360, F1=0.9900 | Val: Loss=0.8050, F1=0.7499
# Epoch  20/500 | Train: Loss=0.3624, F1=0.9867 | Val: Loss=0.7683, F1=0.7976
# Epoch  30/500 | Train: Loss=0.2925, F1=0.9950 | Val: Loss=0.6060, F1=0.8226
# Epoch  40/500 | Train: Loss=0.2629, F1=0.9950 | Val: Loss=0.7117, F1=0.7913
# Epoch  50/500 | Train: Loss=0.2322, F1=1.0000 | Val: Loss=0.7799, F1=0.8051
# Epoch  60/500 | Train: Loss=0.2220, F1=1.0000 | Val: Loss=0.6314, F1=0.8056
# Epoch  70/500 | Train: Loss=0.2223, F1=0.9900 | Val: Loss=1.0730, F1=0.7439
# Epoch  80/500 | Train: Loss=0.1985, F1=0.9983 | Val: Loss=0.4451, F1=0.8610
# Epoch  90/500 | Train: Loss=0.1976, F1=0.9967 | Val: Loss=0.4055, F1=0.8811
# Epoch 100/500 | Train: Loss=0.1899, F1=1.0000 | Val: Loss=0.5649, F1=0.8315
# Epoch 110/500 | Train: Loss=0.1875, F1=1.0000 | Val: Loss=0.5827, F1=0.8121
# Epoch 120/500 | Train: Loss=0.1908, F1=0.9983 | Val: Loss=0.5275, F1=0.8444
# Epoch 130/500 | Train: Loss=0.1829, F1=1.0000 | Val: Loss=0.3727, F1=0.9007
# Epoch 140/500 | Train: Loss=0.1817, F1=1.0000 | Val: Loss=0.5805, F1=0.8507
# Epoch 150/500 | Train: Loss=0.1837, F1=0.9983 | Val: Loss=0.4677, F1=0.8679
# Epoch 160/500 | Train: Loss=0.1790, F1=1.0000 | Val: Loss=0.3920, F1=0.8938
# Epoch 170/500 | Train: Loss=0.1791, F1=1.0000 | Val: Loss=0.5663, F1=0.8441
# Epoch 180/500 | Train: Loss=0.1779, F1=1.0000 | Val: Loss=0.5292, F1=0.8441
# Epoch 190/500 | Train: Loss=0.1773, F1=1.0000 | Val: Loss=0.4683, F1=0.8698
# Epoch 200/500 | Train: Loss=0.1771, F1=1.0000 | Val: Loss=0.4779, F1=0.8632
# Epoch 210/500 | Train: Loss=0.1772, F1=1.0000 | Val: Loss=0.5536, F1=0.8443
# Epoch 220/500 | Train: Loss=0.1772, F1=1.0000 | Val: Loss=0.4591, F1=0.8571
# Epoch 230/500 | Train: Loss=0.1774, F1=1.0000 | Val: Loss=0.5072, F1=0.8568
# Early stopping triggered after 237 epochs.
# Best model restored from epoch 137 with val_f1=0.9275
#
# --- Repeat 3, Fold 1 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3296, F1=0.5746 | Val: Loss=0.6215, F1=0.5333
# Epoch  10/500 | Train: Loss=0.4584, F1=0.9750 | Val: Loss=0.5485, F1=0.8337
# Epoch  20/500 | Train: Loss=0.3458, F1=0.9900 | Val: Loss=0.4140, F1=0.8817
# Epoch  30/500 | Train: Loss=0.2968, F1=0.9967 | Val: Loss=0.4272, F1=0.9002
# Epoch  40/500 | Train: Loss=0.2778, F1=0.9967 | Val: Loss=0.4364, F1=0.9002
# Epoch  50/500 | Train: Loss=0.2602, F1=1.0000 | Val: Loss=0.4532, F1=0.9067
# Epoch  60/500 | Train: Loss=0.2523, F1=1.0000 | Val: Loss=0.4591, F1=0.8938
# Epoch  70/500 | Train: Loss=0.2496, F1=0.9983 | Val: Loss=0.4686, F1=0.8938
# Epoch  80/500 | Train: Loss=0.2449, F1=1.0000 | Val: Loss=0.4743, F1=0.8938
# Epoch  90/500 | Train: Loss=0.2426, F1=1.0000 | Val: Loss=0.4626, F1=0.8938
# Epoch 100/500 | Train: Loss=0.2412, F1=1.0000 | Val: Loss=0.4537, F1=0.8938
# Early stopping triggered after 109 epochs.
# Best model restored from epoch 9 with val_f1=0.9131
#
# --- Repeat 3, Fold 2 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3342, F1=0.5350 | Val: Loss=0.6725, F1=0.6083
# Epoch  10/500 | Train: Loss=0.4584, F1=0.9800 | Val: Loss=0.2913, F1=0.9333
# Epoch  20/500 | Train: Loss=0.3618, F1=0.9817 | Val: Loss=0.4933, F1=0.8133
# Epoch  30/500 | Train: Loss=0.3079, F1=0.9900 | Val: Loss=1.2074, F1=0.6175
# Epoch  40/500 | Train: Loss=0.2770, F1=1.0000 | Val: Loss=0.3492, F1=0.9058
# Epoch  50/500 | Train: Loss=0.2661, F1=1.0000 | Val: Loss=0.3438, F1=0.9129
# Epoch  60/500 | Train: Loss=0.2564, F1=1.0000 | Val: Loss=0.3386, F1=0.8997
# Epoch  70/500 | Train: Loss=0.2510, F1=1.0000 | Val: Loss=0.3437, F1=0.9193
# Epoch  80/500 | Train: Loss=0.2495, F1=0.9983 | Val: Loss=0.3504, F1=0.9259
# Epoch  90/500 | Train: Loss=0.2499, F1=0.9967 | Val: Loss=0.3124, F1=0.8995
# Epoch 100/500 | Train: Loss=0.2442, F1=1.0000 | Val: Loss=0.3728, F1=0.9190
# Epoch 110/500 | Train: Loss=0.2430, F1=1.0000 | Val: Loss=0.3613, F1=0.9259
# Epoch 120/500 | Train: Loss=0.2419, F1=1.0000 | Val: Loss=0.3769, F1=0.9190
# Epoch 130/500 | Train: Loss=0.2418, F1=1.0000 | Val: Loss=0.3685, F1=0.9190
# Epoch 140/500 | Train: Loss=0.2417, F1=1.0000 | Val: Loss=0.3745, F1=0.9190
# Early stopping triggered after 144 epochs.
# Best model restored from epoch 44 with val_f1=0.9397
#
# --- Repeat 3, Fold 3 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3357, F1=0.5380 | Val: Loss=0.6141, F1=0.7111
# Epoch  10/500 | Train: Loss=0.4452, F1=0.9800 | Val: Loss=0.3019, F1=0.9126
# Epoch  20/500 | Train: Loss=0.3830, F1=0.9817 | Val: Loss=0.3898, F1=0.8714
# Epoch  30/500 | Train: Loss=0.3172, F1=0.9883 | Val: Loss=0.2656, F1=0.9366
# Epoch  40/500 | Train: Loss=0.2777, F1=0.9917 | Val: Loss=0.1637, F1=0.9803
# Epoch  50/500 | Train: Loss=0.2483, F1=0.9950 | Val: Loss=0.2053, F1=0.9551
# Epoch  60/500 | Train: Loss=0.2292, F1=0.9983 | Val: Loss=0.2288, F1=0.9489
# Epoch  70/500 | Train: Loss=0.2212, F1=0.9983 | Val: Loss=0.1557, F1=0.9803
# Epoch  80/500 | Train: Loss=0.2145, F1=1.0000 | Val: Loss=0.1712, F1=0.9803
# Epoch  90/500 | Train: Loss=0.2124, F1=1.0000 | Val: Loss=0.1424, F1=0.9868
# Epoch 100/500 | Train: Loss=0.2107, F1=1.0000 | Val: Loss=0.1359, F1=0.9934
# Epoch 110/500 | Train: Loss=0.2097, F1=1.0000 | Val: Loss=0.1578, F1=0.9868
# Epoch 120/500 | Train: Loss=0.2087, F1=1.0000 | Val: Loss=0.1591, F1=0.9868
# Epoch 130/500 | Train: Loss=0.2130, F1=0.9983 | Val: Loss=0.1797, F1=0.9803
# Early stopping triggered after 132 epochs.
# Best model restored from epoch 32 with val_f1=1.0000
#
# --- Repeat 3, Fold 4 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3244, F1=0.5823 | Val: Loss=0.6830, F1=0.5932
# Epoch  10/500 | Train: Loss=0.4374, F1=0.9817 | Val: Loss=0.9899, F1=0.6800
# Epoch  20/500 | Train: Loss=0.3478, F1=0.9850 | Val: Loss=1.3185, F1=0.6284
# Epoch  30/500 | Train: Loss=0.2749, F1=1.0000 | Val: Loss=0.7592, F1=0.7665
# Epoch  40/500 | Train: Loss=0.2548, F1=0.9950 | Val: Loss=0.6143, F1=0.8141
# Epoch  50/500 | Train: Loss=0.2319, F1=1.0000 | Val: Loss=0.8246, F1=0.7286
# Epoch  60/500 | Train: Loss=0.2164, F1=0.9983 | Val: Loss=0.6483, F1=0.8225
# Epoch  70/500 | Train: Loss=0.2030, F1=0.9983 | Val: Loss=0.6126, F1=0.8449
# Epoch  80/500 | Train: Loss=0.1972, F1=1.0000 | Val: Loss=0.8547, F1=0.7551
# Epoch  90/500 | Train: Loss=0.1930, F1=0.9983 | Val: Loss=0.6287, F1=0.8193
# Epoch 100/500 | Train: Loss=0.1920, F1=1.0000 | Val: Loss=0.6546, F1=0.8204
# Epoch 110/500 | Train: Loss=0.1894, F1=1.0000 | Val: Loss=0.6900, F1=0.7940
# Epoch 120/500 | Train: Loss=0.1890, F1=1.0000 | Val: Loss=0.6496, F1=0.8193
# Epoch 130/500 | Train: Loss=0.1879, F1=1.0000 | Val: Loss=0.6364, F1=0.8193
# Epoch 140/500 | Train: Loss=0.1877, F1=1.0000 | Val: Loss=0.6207, F1=0.8256
# Epoch 150/500 | Train: Loss=0.1875, F1=1.0000 | Val: Loss=0.5972, F1=0.8193
# Early stopping triggered after 153 epochs.
# Best model restored from epoch 53 with val_f1=0.8449
#
# --- Repeat 3, Fold 5 ---
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.3264, F1=0.6008 | Val: Loss=0.6667, F1=0.4469
# Epoch  10/500 | Train: Loss=0.4773, F1=0.9650 | Val: Loss=0.5556, F1=0.7822
# Epoch  20/500 | Train: Loss=0.3451, F1=0.9967 | Val: Loss=0.6318, F1=0.7963
# Epoch  30/500 | Train: Loss=0.3094, F1=0.9883 | Val: Loss=0.9664, F1=0.7432
# Epoch  40/500 | Train: Loss=0.2630, F1=0.9967 | Val: Loss=0.4288, F1=0.8605
# Epoch  50/500 | Train: Loss=0.2437, F1=1.0000 | Val: Loss=0.4843, F1=0.8777
# Epoch  60/500 | Train: Loss=0.2349, F1=1.0000 | Val: Loss=0.4628, F1=0.8653
# Epoch  70/500 | Train: Loss=0.2289, F1=1.0000 | Val: Loss=0.4466, F1=0.8842
# Epoch  80/500 | Train: Loss=0.2229, F1=1.0000 | Val: Loss=0.4728, F1=0.8718
# Epoch  90/500 | Train: Loss=0.2240, F1=0.9950 | Val: Loss=0.4174, F1=0.8913
# Epoch 100/500 | Train: Loss=0.2165, F1=1.0000 | Val: Loss=0.5199, F1=0.8712
# Epoch 110/500 | Train: Loss=0.2157, F1=1.0000 | Val: Loss=0.4631, F1=0.8783
# Epoch 120/500 | Train: Loss=0.2135, F1=1.0000 | Val: Loss=0.4443, F1=0.8853
# Epoch 130/500 | Train: Loss=0.2122, F1=1.0000 | Val: Loss=0.4426, F1=0.8853
# Epoch 140/500 | Train: Loss=0.2116, F1=1.0000 | Val: Loss=0.4592, F1=0.8853
# Epoch 150/500 | Train: Loss=0.2114, F1=1.0000 | Val: Loss=0.4424, F1=0.8853
# Epoch 160/500 | Train: Loss=0.2105, F1=1.0000 | Val: Loss=0.4450, F1=0.8723
# Epoch 170/500 | Train: Loss=0.2097, F1=1.0000 | Val: Loss=0.4660, F1=0.8783
# Epoch 180/500 | Train: Loss=0.2096, F1=1.0000 | Val: Loss=0.4691, F1=0.8718
# Early stopping triggered after 188 epochs.
# Best model restored from epoch 88 with val_f1=0.9192
#
# === Cross-validated results with Optuna best_params ===
# Accuracy: 0.9298 ± 0.0311
# F1 score: 0.9296 ± 0.0322
# Precision: 0.9360 ± 0.0261
# Recall: 0.9298 ± 0.0311
